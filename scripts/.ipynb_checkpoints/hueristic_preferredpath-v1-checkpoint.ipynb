# %% [markdown]
# ## Hueristic to improve preferred path for ancestor node

# %%
# libraries
from ete3 import Tree
from pysam import FastaFile
from scipy.spatial.distance import hamming
import re
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# class - to load tree, load sequences, neighbours, pogs, hamming distance, overall score for a given tree.

class PhyloTree:
    
    def __init__(self,nwk_file_path,ancestor_fasta_file,json_pogs_file):
        ''' initialise the PhyloTree Class '''
        tree_file = open(nwk_file_path,"r")
        my_tree = tree_file.read() + ";"
        self.tree = Tree(my_tree, format=1)
        self.total_indel_parsi_score = 0
        self.patience = 3
        self.all_ancestor_nodes = []
        self.all_ancestor_pogs_path = []
        self.ancestor_fasta_file = ancestor_fasta_file
        self.json_pogs_file = json_pogs_file
        self.folder_to_save_numpy_arrays = '/'.join(self.json_pogs_file.split('/')[0:-1]) + '/'
               
        
    def hamming_distance(self,str1,str2):
        ''' indel hamming distance between 2 sequences '''
        #str1 =  re.sub('[a-zA-Z]', 'a', str1)
        #str2 =  re.sub('[a-zA-Z]', 'a', str2)
        return hamming(list(str1), list(str2)) * len(str1)
        
    def load_attributes(self):
        ''' load node attributes - sequences, neighbours, hamming distance '''
        sequences_info = FastaFile(self.ancestor_fasta_file)
        
        for n in self.tree.traverse():
            node_avg_distance = 0
            ancestor_nodes_info = {}
            neighbour_list = []
            neighbour_sequence_list = []
            neighbour_dist_list = [] 
                
            if n.is_leaf() == False:    
                # add node sequence on the tree
                #n.add_features(sequence = sequences_info.fetch(n.name))
                current_node_sequence = sequences_info.fetch(n.name)
                
                for c in n.children:
                    child_sequence = sequences_info.fetch(c.name)
                    neighbour_list.append(c.name)
                    neighbour_sequence_list.append(child_sequence)
                    neighbour_dist_list.append(self.hamming_distance(current_node_sequence,child_sequence))
                    
                if n.is_root() == False:
                    parent_sequence = sequences_info.fetch(n.up.name)
                    neighbour_list.append(n.up.name)
                    neighbour_sequence_list.append(parent_sequence)
                    neighbour_dist_list.append(self.hamming_distance(current_node_sequence,parent_sequence))
                    
            
                node_avg_distance = sum(neighbour_dist_list) / len(neighbour_dist_list) 
                
                # add neighbor sequences on the tree
                #n.add_features(neighbour_sequence = neighbour_sequence_list)
                
            
            sequence_simple =  re.sub('[a-zA-Z]', 'a', sequences_info.fetch(n.name))
            self.total_indel_parsi_score += node_avg_distance # total tree score
            ancestor_nodes_info['name'] = n.name
            ancestor_nodes_info['sequence'] = sequence_simple
            ancestor_nodes_info['node_neighbors'] = neighbour_list
            ancestor_nodes_info['avg_indel_distance'] = node_avg_distance
            ancestor_nodes_info['node_neighbors_distance'] = neighbour_dist_list
            self.all_ancestor_nodes.append(ancestor_nodes_info)
        
        #print(self.all_ancestor_nodes)
        
                
    def count_path(self,a):
        ''' count the number of paths in a graph '''
        a = a + a.T    #add up the transpose
        a = np.clip(a,0,1)
        a = np.triu(a) #only the upper triangle

        nodes = a.shape[0]
        dp = [0] * nodes
        dp[nodes - 1]= 1 #last node

        for i in range(nodes - 1, -1, -1):
            neighbour_nodes = np.where (a[i] == 1)[0]
            for j in neighbour_nodes:
                dp[i] = dp[i] + dp[j]

        return(dp[0])
        
    
    def paths_in_pogs_cnt(self):
        ''' total paths in the pogs for ancestor nodes '''
        ''' save pogs as numpy array '''
        
        total_sequences_list = []
        all_exp_results = []
        
        # read the json file
        with open(self.json_pogs_file, 'r') as j:
            pog_all_data = json.loads(j.read())

            # read all ancestors
            for node_type in ['Ancestors','Extants']:
                for pog_data in pog_all_data[node_type]:
                    
                    pog_path_dict = {}
                    
                    if node_type == 'Ancestors':
                        node_name = 'N' + pog_data['Name']
                    else:
                        node_name = pog_data['Name']
                    
                    pog_path_dict['name'] = node_name

                    # read that node's data
                    nodes = pog_data['Size'] + 2

                    # create numpy zero matrix
                    mat = np.zeros(shape=(nodes,nodes))

                    # Edges from special Start node to the start nodes
                    for s in pog_data['Starts']:
                        mat[0,s + 1] = 1

                    # Edges from last node to the special End node
                    for e in pog_data['Ends']:
                        mat[e + 1,nodes-1] = 1

                    # create the adjency matrix for all nodes except from special node start
                    for ind,node in enumerate(pog_data['Indices']):
                        row_mat = node
                        row_col = pog_data['Adjacent'][ind]

                        for rc in row_col:
                            mat[row_mat + 1,rc + 1] = 1
                        

                    # count the number of viable paths from the POG
                    total_sequences = self.count_path(mat)

                    pog_path_dict['total_paths'] = total_sequences

                    self.all_ancestor_pogs_path.append(pog_path_dict)

                    # save pogs as numpy array ( needed later for markov chain hueristic)

                    # convert bidirectional mat into unidirectional
                    mat = mat + mat.T     #add up the transpose
                    mat = np.clip(mat,0,1)
                    mat = np.triu(mat)   #only the upper triangle

                    # save numpy array in file
                    mat_file_name = self.folder_to_save_numpy_arrays +  node_name + '.npy'
                    np.save(mat_file_name,mat)
                
    
    def create_mc_model(self,node_to_improve,neighbor_list):
        ''' Markov chain model to find preferred path for a ancestor node.
            Each position in the sequence is a state in the markov chain model.'''
        
        #pseudocount    = 0.0001
        total_states   = np.load(self.folder_to_save_numpy_arrays + neighbor_list[0] + '.npy').shape[0]    
        mc_model       = np.full((total_states, total_states),0)   
        
        # sum up the neighbor pog array
        for n in neighbor_list:
            m = np.load(self.folder_to_save_numpy_arrays + n + '.npy')
            mc_model = np.add(mc_model,m)
            
        # project the neighbour markov chain into the current node
        # if the path does not exists in the current node, change the value to 0
        current_node_np = np.load(self.folder_to_save_numpy_arrays + node_to_improve + '.npy')
        
        # node not present will be wiped out
        mc_model = mc_model * current_node_np
        
        # add the current node and neighbour arrays to create a markov chain on the current node
        mc_model = np.add(mc_model,current_node_np)
        
        # add pseudocounts for 0 entries
        #mc_model[mc_model == 0] = pseudocount
        
        # convert into probabilities row wise
        #mc_model = np.round(mc_model/mc_model.sum(axis=1)[:,None] ,5)
        return mc_model
        
    
    
    def mc_inference(self,mc_model):
        ''' markov chain inference to find the most probable path '''
        total_nodes = mc_model.shape[0] # total nodes to traverse
        pf    = [0] * total_nodes       # preferred path
        pf[0] = 1                       # starting node is always traversed

        i= 0
        while(i < total_nodes-1):       # till we reach the end of the nodes
            tr_ind = np.where(mc_model[i] == np.amax(mc_model[i]))[0][0] # 1st element if more than 1 returned
            pf[int(tr_ind)] = 1
            i = tr_ind
            
        pf = pf [1:-1] # return path except for the first and last path
        return pf

    
    def calculate_score(self,mc_output,node_to_improve,neighbor_list,current_score):
        
        neighbour_dist_list = []
        
        # replace 1 by a and 0 by - for hamming distance calculation
        mc_output_sequence = ['a' if item == 1 else '-' for item in mc_output] 
        mc_output_sequence = ''.join(mc_output_sequence)
        
        
        # node dataframe rows
        node_df_info = self.combined_df[self.combined_df['name'] == node_to_improve]
        current_indel_distance = float(node_df_info['avg_indel_distance'].to_string(index=False))
        current_sequence = node_df_info['sequence'].to_string(index=False)
        
        # recalculate score w.r.t neighbors
        for n in neighbor_list:
            neighbor_sequence = self.combined_df[self.combined_df['name'] == \
                                              n]['sequence'].to_string(index=False)
            
            #print("Neighbor_Sequence",neighbor_sequence)
            neighbour_dist_list.append(self.hamming_distance(mc_output_sequence,neighbor_sequence))
        
        # avg indel distance
        avg_indel_distance = sum(neighbour_dist_list) / len(neighbour_dist_list) 
        
        # marked node as visited
        self.combined_df.loc[self.combined_df['name'] == node_to_improve, 'visited'] = True
        
        
        if avg_indel_distance < current_indel_distance: # recalculate neigh distance again
            
            print('NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE')
            print("BEFORE AVERAGE INDEL DISTANCE::",current_indel_distance)
            print("NEW AVERAGE INDEL DISTANCE::",avg_indel_distance)
            
            print("BEFORE SEQUENCE:",current_sequence)
            print("AFTER SEQUENCE:",mc_output_sequence)
            
            # update the dataframe combined_df for the node being improved
            self.combined_df.loc[self.combined_df['name'] == node_to_improve,'avg_indel_distance'] \
                                            = avg_indel_distance
            self.combined_df.loc[self.combined_df['name'] == node_to_improve,'node_neighbors_distance']\
                                            = 0
            
            
            for n in neighbor_list:
                neighbor_sequence = self.combined_df[self.combined_df['name'] == \
                                              n]['sequence'].to_string(index=False)
                
                n_neighbour_dist_list = []
                n_neighbor_list = self.combined_df[self.combined_df['name'] == \
                                              n]['node_neighbors'].tolist()[0]
                if len(n_neighbor_list) != 0:
                    for n in n_neighbor_list:
                        n_neighbor_sequence = self.combined_df[self.combined_df['name'] == \
                                                          n]['sequence'].to_string(index=False)
                        n_neighbour_dist_list.append(self.hamming_distance(neighbor_sequence,n_neighbor_sequence))

                    n_avg_indel_distance = sum(n_neighbour_dist_list) / len(n_neighbour_dist_list)
                    
                    # update the neighbor distance data
                    self.combined_df.loc[self.combined_df['name'] == n,'avg_indel_distance'] \
                                            = n_avg_indel_distance
                    self.combined_df.loc[self.combined_df['name'] == n,'node_neighbors_distance']\
                                            = 0
        
            # new score
            score = self.combined_df['avg_indel_distance'].sum()
            score_improve_flag = 1
            
        else:
            score = current_score
            score_improve_flag = 0
            
            
        return score,score_improve_flag
        
    
    def markov_chain_neighbor(self,node_to_improve,neighbor_list,current_score):
        ''' markov chain method to find preferred path '''
        
        # create model
        mc_model  = self.create_mc_model(node_to_improve,neighbor_list)
        #print("mc_model",mc_model)
        # perform inference
        mc_output = self.mc_inference(mc_model)
        #print("mc_output",mc_output)
        # evaluate score
        new_score,score_improve_flag = self.calculate_score(mc_output,node_to_improve,neighbor_list,current_score)
        
        return score_improve_flag,new_score
        
    
    def score_visual(self,score_history):
        ''' visualise score improvement '''
        plt.plot(*zip(*score_history))
        plt.title('SCORE IMPROVEMENT HISTORY')
        plt.xlabel('ITERATION')
        plt.ylabel('TREE - INDEL PARSIMONY SCORE')
        plt.show()
                
    def hueristic_preferred_path(self):
        ''' hueristic algorithm to improve the overall tree score by selecting alternative preferred path '''
        
        # 1 - create a combined dataframe
        self.combined_df = pd.merge(pd.DataFrame(self.all_ancestor_nodes),\
                                pd.DataFrame(self.all_ancestor_pogs_path),how='left')
        
        
        # 2 - add nodes with only 1 path in the visited nodes list
        self.combined_df['visited'] = self.combined_df['total_paths'] == 1
        
        # 2 - mark all nodes are not improved
        self.combined_df['improved'] = 0
        
        
        # 3 - add rank for the nodes based on distance from neighbors
        self.combined_df['rank_distance'] = self.combined_df['avg_indel_distance'].rank()
        self.combined_df['rank_pathcnts'] = self.combined_df['total_paths'].rank()
        self.combined_df['total_rank']    = self.combined_df['rank_distance'] + self.combined_df['rank_pathcnts'] 
        pd.set_option('display.max_colwidth', None)
        display(self.combined_df.head(5))
        
        # 4 - parameters for hueristic
        total_iterations      = sum(self.combined_df['visited'] == False)
        score_not_improve_cnt = 0
        score_track           = []
        current_score = self.combined_df['avg_indel_distance'].sum()
        score_track.append((0,current_score))
        print("TOTAL POTENTIAL NODES FOR IMPROVEMENT::",total_iterations)
        
        # 5 - hueristic loop
        for i in range(1,total_iterations+1):
            
            print("ITERATION::",i)
            current_score = self.combined_df['avg_indel_distance'].sum()
            print("CURRENT SCORE::", current_score)
            
            # pick node with max rank and which has not been visited
            df_filtered = self.combined_df[self.combined_df['visited'] == False].reset_index()    
            max_df_row  = df_filtered.iloc[df_filtered['total_rank'].idxmax()]
            node_to_improve = max_df_row['name']
            node_neighbors = self.combined_df[self.combined_df['name'] == \
                                              node_to_improve]['node_neighbors'].tolist()[0]
            print("NODE SELECTED FOR IMPROVEMENT::",node_to_improve)
#             print('NEIGHBOURS::',node_neighbors)
            
            # improve indel score here by choosing alternate path
            score_improve_flag,new_score = self.markov_chain_neighbor(node_to_improve,node_neighbors,current_score)
            
            
            
            if score_improve_flag == 1:
                print("SCORE IMPROVED FROM:{} TO {}".format(current_score,new_score))
                # update node as improved
                self.combined_df.loc[self.combined_df['name']== node_to_improve,'improved'] = 1
                score_not_improve_cnt = 0 # reset counter 
            else:
                print("SCORE DID NOT IMPROVE")
                score_not_improve_cnt += 1 # update the consecutive score improvement
            
            if score_not_improve_cnt >= self.patience:
                print("EXITING AS SCORE DID NOT IMROVE FOR LAST {} ITERATIONS".format(self.patience))
                break
            
            score_track.append((i,new_score))
        print("TOTAL NODES IMPROVED::",sum(self.combined_df['improved']))
        
        return score_track

# %%
# input files for the algorithm

# ## sample tree
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/pogs.json'

# ## CYP2U
nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/grasp_ancestors.nwk'
ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/grasp_ancestors.fa"
pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/pogs.json'


### another sample tree
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/pogs.json'

# hueristic steps
asrtree = PhyloTree(nwk_file_path,ancestor_fasta_file,pogs_file)
asrtree.load_attributes ()
asrtree.paths_in_pogs_cnt()
score_history = asrtree.hueristic_preferred_path()
# Out:
#              name  \
# 0              N0
# 1              N1
# 2  XP_020383892.1
# 3              N2
# 4             N46
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             sequence  \
# 0  a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa--aaaaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# 1  a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# 2  a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa--aaaaa---aaaaaaaaaaaa---aaa-aaa--aaaaaaaaaaaaaaa-----aaaaaaaaaa--------a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# 3  a----------aaaa-------------aaaa----aaaaaaaaaaa-aa-------aaa---aaaaaaaaaa-----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# 4  a----------aaaaa--------------------aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
#
#              node_neighbors  avg_indel_distance node_neighbors_distance  \
# 0      [N1, XP_020383892.1]           96.000000           [88.0, 104.0]
# 1             [N2, N46, N0]           67.666667      [80.0, 35.0, 88.0]
# 2                        []            0.000000                      []
# 3  [XP_006629927.2, N3, N1]           66.333333      [98.0, 21.0, 80.0]
# 4            [N47, N50, N1]           34.000000      [21.0, 46.0, 35.0]
#
#    total_paths  visited  improved  rank_distance  rank_pathcnts  total_rank
# 0          288    False         0          329.0          329.0       658.0
# 1           36    False         0          326.0          326.0       652.0
# 2            1     True         0           84.5          144.5       229.0
# 3           32    False         0          325.0          324.5       649.5
# 4           60    False         0          280.5          327.0       607.5
# TOTAL POTENTIAL NODES FOR IMPROVEMENT:: 41
# ITERATION:: 1
# CURRENT SCORE:: 3991.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N0
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 96.0
# NEW AVERAGE INDEL DISTANCE:: 8.999999999999998
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa--aaaaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa--aaaaa---aaaaaaaaaaaa---aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3991.0000000000005 TO 3904.0000000000005
# ITERATION:: 2
# CURRENT SCORE:: 3904.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N1
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 67.666667
# NEW AVERAGE INDEL DISTANCE:: 10.666666666666666
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaa----aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaaa---aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3904.0000000000005 TO 3852.0000000000005
# ITERATION:: 3
# CURRENT SCORE:: 3852.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N2
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 66.333333
# NEW AVERAGE INDEL DISTANCE:: 8.333333333333334
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa-------aaa---aaaaaaaaaa-----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaa----aaaaaaaaaaaaaa-------aaa---aaaaaaaaaa-----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3852.0000000000005 TO 3789.3333333333335
# ITERATION:: 4
# CURRENT SCORE:: 3789.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N3
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 66.0
# NEW AVERAGE INDEL DISTANCE:: 5.333333333333333
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa-------aaa---aaaaaaaaaa-----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaa----aaaaaaaaaaaaaa-------aaa---aaaaaaaaaaaa---aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3789.3333333333335 TO 3726.3333333333335
# ITERATION:: 5
# CURRENT SCORE:: 3726.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N50
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 64.333333
# NEW AVERAGE INDEL DISTANCE:: 14.333333333333334
# BEFORE SEQUENCE: a----------aaaaa-------------------------------aaa-aa----aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaaaa--aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3726.3333333333335 TO 3674.3333333333335
# ITERATION:: 6
# CURRENT SCORE:: 3674.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N47
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 66.0
# NEW AVERAGE INDEL DISTANCE:: 9.333333333333334
# BEFORE SEQUENCE: a----------aaaaa--------------------aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaa----aaaaaaaaaaaaaa-aa----aaa---aaaaaaaaaaa----aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3674.3333333333335 TO 3614.666666666667
# ITERATION:: 7
# CURRENT SCORE:: 3614.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N82
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 68.333333
# NEW AVERAGE INDEL DISTANCE:: 12.666666666666666
# BEFORE SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaaaa---------aaaaaaa-aa----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa-aaaa-aaaaaaaaaaaa---------aaaaaaa-aa----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3614.666666666667 TO 3533.3333333333335
# ITERATION:: 8
# CURRENT SCORE:: 3533.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N55
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 76.666667
# NEW AVERAGE INDEL DISTANCE:: 26.0
# BEFORE SEQUENCE: a----------aaaa--------aaaaa----------aaaaaaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aaaaaa---aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--------aaaaa----------aaaaaaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa---aaaaaa---aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3533.3333333333335 TO 3469.0000000000005
# ITERATION:: 9
# CURRENT SCORE:: 3469.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N52
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 65.666667
# NEW AVERAGE INDEL DISTANCE:: 29.333333333333332
# BEFORE SEQUENCE: a----------aaaa--------aaaaaaa---------aaaaaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--------aaaaaaa---------aaaaaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3469.0000000000005 TO 3419.666666666667
# ITERATION:: 10
# CURRENT SCORE:: 3419.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N57
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 59.666667
# NEW AVERAGE INDEL DISTANCE:: 12.666666666666666
# BEFORE SEQUENCE: a----------aaaa---------------------------------aa-------aaa---aaaaaaaaaaa----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa-------------------------------aaa-------aaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3419.666666666667 TO 3341.0000000000005
# ITERATION:: 11
# CURRENT SCORE:: 3341.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N48
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 65.666667
# NEW AVERAGE INDEL DISTANCE:: 6.666666666666667
# BEFORE SEQUENCE: a----------aaaaa------------aaaa-a--aaaaaaaaaaaaaa-aaaaaaaaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa-aaaaaa--aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa------------aaaaaa--aaaaaaaaaaaaaa-aaaaaaaaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa-aaaaaa--aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3341.0000000000005 TO 3265.0000000000005
# ITERATION:: 12
# CURRENT SCORE:: 3265.0000000000005
# NODE SELECTED FOR IMPROVEMENT:: N19
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 58.0
# NEW AVERAGE INDEL DISTANCE:: 6.333333333333333
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:3265.0000000000005 TO 3186.3333333333335
# ITERATION:: 13
# CURRENT SCORE:: 3186.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N33
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 40.666667
# NEW AVERAGE INDEL DISTANCE:: 2.6666666666666665
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# SCORE IMPROVED FROM:3186.3333333333335 TO 3142.666666666667
# ITERATION:: 14
# CURRENT SCORE:: 3142.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N7
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 45.666667
# NEW AVERAGE INDEL DISTANCE:: 3.666666666666666
# BEFORE SEQUENCE: a----------aaaaa----------aaaaaa-----aaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa----------aaaaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:3142.666666666667 TO 3069.0
# ITERATION:: 15
# CURRENT SCORE:: 3069.0
# NODE SELECTED FOR IMPROVEMENT:: N24
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 56.666667
# NEW AVERAGE INDEL DISTANCE:: 4.666666666666667
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:3069.0 TO 2984.666666666667
# ITERATION:: 16
# CURRENT SCORE:: 2984.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N38
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 44.333333
# NEW AVERAGE INDEL DISTANCE:: 4.999999999999999
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# SCORE IMPROVED FROM:2984.666666666667 TO 2945.333333333334
# ITERATION:: 17
# CURRENT SCORE:: 2945.333333333334
# NODE SELECTED FOR IMPROVEMENT:: N129
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 56.666667
# NEW AVERAGE INDEL DISTANCE:: 12.33333333333333
# BEFORE SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaaaaa-aaaaaaaa--------a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--a--------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaaaaa-aaaaaaaa--------a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2945.333333333334 TO 2902.0
# ITERATION:: 18
# CURRENT SCORE:: 2902.0
# NODE SELECTED FOR IMPROVEMENT:: N15
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 52.666667
# NEW AVERAGE INDEL DISTANCE:: 1.6666666666666667
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aaa------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aaa------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2902.0 TO 2849.3333333333335
# ITERATION:: 19
# CURRENT SCORE:: 2849.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N130
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 51.666667
# NEW AVERAGE INDEL DISTANCE:: 14.666666666666666
# BEFORE SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaa-------------aaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa------------------aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaa-------------aaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa------------------aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2849.3333333333335 TO 2823.666666666667
# ITERATION:: 20
# CURRENT SCORE:: 2823.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N46
# SCORE DID NOT IMPROVE
# ITERATION:: 21
# CURRENT SCORE:: 2823.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N20
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 40.666667
# NEW AVERAGE INDEL DISTANCE:: 4.333333333333333
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a-----------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a------------aaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2823.666666666667 TO 2747.0
# ITERATION:: 22
# CURRENT SCORE:: 2747.0
# NODE SELECTED FOR IMPROVEMENT:: N96
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 48.666667
# NEW AVERAGE INDEL DISTANCE:: 18.0
# BEFORE SEQUENCE: a----------aaaa--aaa--aaaaaaaaaaaaa-aaaaaaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--aaaa-aaaaaaaaaaaaa-aaaaaaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2747.0 TO 2672.0
# ITERATION:: 23
# CURRENT SCORE:: 2672.0
# NODE SELECTED FOR IMPROVEMENT:: N6
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 45.333333
# NEW AVERAGE INDEL DISTANCE:: 2.0
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2672.0 TO 2623.3333333333335
# ITERATION:: 24
# CURRENT SCORE:: 2623.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N51
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 7.0
# NEW AVERAGE INDEL DISTANCE:: 6.666666666666667
# BEFORE SEQUENCE: a----------aaaa--------aaaaaaa---------aaaaaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--------aaaaaaa------------aaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------aaaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2623.3333333333335 TO 2634.0
# ITERATION:: 25
# CURRENT SCORE:: 2634.0
# NODE SELECTED FOR IMPROVEMENT:: N14
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 6.333333
# NEW AVERAGE INDEL DISTANCE:: 3.6666666666666665
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aaa------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---a--------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2634.0 TO 2634.0
# ITERATION:: 26
# CURRENT SCORE:: 2634.0
# NODE SELECTED FOR IMPROVEMENT:: N37
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 32.333333
# NEW AVERAGE INDEL DISTANCE:: 2.6666666666666665
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------------a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaa----------
# SCORE IMPROVED FROM:2634.0 TO 2587.3333333333335
# ITERATION:: 27
# CURRENT SCORE:: 2587.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N58
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 40.666667
# NEW AVERAGE INDEL DISTANCE:: 4.333333333333333
# BEFORE SEQUENCE: a----------aaaa---------------------------------aa--a----aaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------aaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaaa-------------------------------aaa--a----aaa---aaaaaaaaaaa----aaa-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---------------aaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2587.3333333333335 TO 2531.0
# ITERATION:: 28
# CURRENT SCORE:: 2531.0
# NODE SELECTED FOR IMPROVEMENT:: N81
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 39.666667
# NEW AVERAGE INDEL DISTANCE:: 26.666666666666668
# BEFORE SEQUENCE: --------------------------------------------------------------------------------------------------------------------------------------------a--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: ------------------------------------------------------------------------------------------------------------aaaaaaaaa-----------------------a--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2531.0 TO 2481.0
# ITERATION:: 29
# CURRENT SCORE:: 2481.0
# NODE SELECTED FOR IMPROVEMENT:: N136
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 39.0
# NEW AVERAGE INDEL DISTANCE:: 0.6666666666666666
# BEFORE SEQUENCE: a----------aaaa--aaaa-aaaaaaaa---------aaaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aa---------------aaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--aaaa-aaaaaaaa---------aaaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aa---------------aaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2481.0 TO 2418.0
# ITERATION:: 30
# CURRENT SCORE:: 2418.0
# NODE SELECTED FOR IMPROVEMENT:: N39
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 38.0
# NEW AVERAGE INDEL DISTANCE:: 1.6666666666666667
# BEFORE SEQUENCE: a----------aa-a-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------
# SCORE IMPROVED FROM:2418.0 TO 2384.0
# ITERATION:: 31
# CURRENT SCORE:: 2384.0
# NODE SELECTED FOR IMPROVEMENT:: N134
# SCORE DID NOT IMPROVE
# ITERATION:: 32
# CURRENT SCORE:: 2384.0
# NODE SELECTED FOR IMPROVEMENT:: N135
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 29.666667
# NEW AVERAGE INDEL DISTANCE:: 7.333333333333333
# BEFORE SEQUENCE: a----------aaaa--aaaa-aaaaaaa----------aaaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aa---------------aaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--aaaa-aaaaaaaaa---------aaaaaaaaaa--a----aaa---aaaaaaaaaaa-----aa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa---aa-------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2384.0 TO 2341.666666666667
# ITERATION:: 33
# CURRENT SCORE:: 2341.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N22
# SCORE DID NOT IMPROVE
# ITERATION:: 34
# CURRENT SCORE:: 2341.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N77
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 33.0
# NEW AVERAGE INDEL DISTANCE:: 26.0
# BEFORE SEQUENCE: -----------------------------------------------------------------------------------------------------------------------------------------aaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: -------------------------------------------------------------------------------------------------------------a--------------------------aaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2341.666666666667 TO 2359.3333333333335
# ITERATION:: 35
# CURRENT SCORE:: 2359.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N56
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 12.333333
# NEW AVERAGE INDEL DISTANCE:: 6.666666666666667
# BEFORE SEQUENCE: a----------aaaa--------aaaaaaa------------aaaaaaaa-------aaa---aaaaaaaaaaa----aa---aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--------aaaaaaa------------aaaaaaaa-------aaa---aaaaaaaaaaa----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2359.3333333333335 TO 2359.3333333333335
# ITERATION:: 36
# CURRENT SCORE:: 2359.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N32
# SCORE DID NOT IMPROVE
# ITERATION:: 37
# CURRENT SCORE:: 2359.3333333333335
# NODE SELECTED FOR IMPROVEMENT:: N27
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 28.0
# NEW AVERAGE INDEL DISTANCE:: 1.0
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2359.3333333333335 TO 2333.666666666667
# ITERATION:: 38
# CURRENT SCORE:: 2333.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N64
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 18.333333
# NEW AVERAGE INDEL DISTANCE:: 16.333333333333332
# BEFORE SEQUENCE: a----------aaaa--------aaaaaa------------aaaaaaaaa-------aaa---aaaaaaaaaaa----a-aaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# AFTER SEQUENCE: a----------aaaa--------aaaaaa------------aaaaaaaaa-------aaa---aaaaaaaaaaa----aaaaaaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa------------aaaaaaa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-----aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---aaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa---------------------
# SCORE IMPROVED FROM:2333.666666666667 TO 2300.666666666667
# ITERATION:: 39
# CURRENT SCORE:: 2300.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N21
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 12.0
# NEW AVERAGE INDEL DISTANCE:: 1.3333333333333333
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2300.666666666667 TO 2289.666666666667
# ITERATION:: 40
# CURRENT SCORE:: 2289.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N23
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 11.666667
# NEW AVERAGE INDEL DISTANCE:: 2.3333333333333335
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2289.666666666667 TO 2279.666666666667
# ITERATION:: 41
# CURRENT SCORE:: 2279.666666666667
# NODE SELECTED FOR IMPROVEMENT:: N28
# NEW INDEL DISTANCE IS LESS THAN THE CURRENT INDEL DISTANCE
# BEFORE AVERAGE INDEL DISTANCE:: 3.666667
# NEW AVERAGE INDEL DISTANCE:: 2.333333333333333
# BEFORE SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# AFTER SEQUENCE: a----------aaaa-------------aaaa----aaaaaaaaaaa-aa--a----aaa---aaaaaaaaaa-----aaa--aa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaa-----------------aa--a-aaa--aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa-aaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--aaaaaaaa-aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa--------------------
# SCORE IMPROVED FROM:2279.666666666667 TO 2279.0
# TOTAL NODES IMPROVED:: 37

# %%
asrtree.score_visual(score_history)
