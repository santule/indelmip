# %% [markdown]
# ## MIP Program for choosing preferred path for ancestor nodes.
# 1. Program - Gurobi Solver
# 2. Date - 5 September 2022

# %%
# libraries
import gurobipy as gp
from gurobipy import abs_,quicksum
from gurobipy import GRB
import time
import json
from collections import defaultdict
from ete3 import Tree
import numpy as np
from pysam import FastaFile
import re

# %% [markdown]
# ## MIP INPUT

# %%
''' Convert the json pogs file to the data structure needed for MIP Model'''
''' Information needed 
extant list - list of all extant nodes
sequence length
total nodes in the tree
edges from position in the node
edges to the position in the node
fully connected, start, end, single connected and unconnected positions
'''


class Pogs:
    def __init__(self,pogs_file,tree_file):
        
        self.json_pogs_file = pogs_file
        tree_file = open(nwk_file_path,"r")
        my_tree = tree_file.read() + ";"
        self.tree = Tree(my_tree, format=1)
        self.node_path_dict = {}
        self.node_path_reverse_dict = {}
        self.tree_neighbor_dict = defaultdict(list)
        self.node_type_dict = defaultdict(list)
        self.node_pogs_cnt = {}
        self.node_pogs = {}
        self.extant_list = []
        self.nodes = 0
          
    def count_path(self,a):
        ''' count the number of paths in a graph '''
        a = a + a.T    #add up the transpose
        a = np.clip(a,0,1)
        a = np.triu(a) #only the upper triangle

        nodes = a.shape[0]
        dp = [0] * nodes
        dp[nodes - 1]= 1 #last node

        for i in range(nodes - 1, -1, -1):
            neighbour_nodes = np.where (a[i] == 1)[0]
            for j in neighbour_nodes:
                dp[i] = dp[i] + dp[j]

        return(dp[0])
    
    def create_neighbor_object(self):
        ''' create neighbor dict '''
        
        for n in self.tree.traverse():
            if n.is_leaf() == False:    
                for c in n.children:
                    self.tree_neighbor_dict[n.name] += [c.name]
        return self.tree_neighbor_dict
                
    def create_node_info_dict(self):
        ''' create edge dictionary and other node information'''
        '''Example output-- {\
                  1:{0:[1,2],1:[2,3,4],2:[3,4],3:[4],4:[5]} ,\
                  2:{0:[1],1:[2],2:[3],3:[4],4:[5]} \
                  } '''
        # read the json file
        with open(self.json_pogs_file, 'r') as j:
            pog_all_data = json.loads(j.read())

            # read all ancestors
            for node_type in ['Ancestors','Extants']:
                for pog_data in pog_all_data[node_type]:
                    if node_type == 'Ancestors':
                        node_name = 'N' + pog_data['Name']
                    else:
                        node_name = pog_data['Name']
                        self.extant_list.append(node_name)
                        
                    node_edges_info_dict = defaultdict(list)
                    node_edges_reverse_info_dict = defaultdict(list)
                    
                    # read that node's data
                    self.nodes = pog_data['Size'] + 2
                    mat = np.zeros(shape=(self.nodes,self.nodes))
                    
                    # Edges from special Start node to the start nodes
                    for s in pog_data['Starts']:
                        node_edges_info_dict[0] += [s+1] 
                        node_edges_reverse_info_dict[s+1] += [0]
                        mat[0,s + 1] = 1
                       
                    # Edges from last node to the special End node
                    for e in pog_data['Ends']:
                        node_edges_info_dict[e + 1] += [self.nodes-1]
                        node_edges_reverse_info_dict[self.nodes-1] += [e + 1]
                        mat[e + 1,self.nodes-1] = 1
                        
                        
                    # create the adjency matrix for all nodes except from special node start
                    for ind,node in enumerate(pog_data['Indices']):
                        row_mat = node
                        row_col = pog_data['Adjacent'][ind]

                        for rc in row_col:
                            node_edges_info_dict[row_mat + 1] += [rc + 1]
                            node_edges_reverse_info_dict[rc + 1] += [row_mat + 1]
                            mat[row_mat + 1,rc + 1] = 1
                            
                    # put all info together in the final dict
                    self.node_path_dict[node_name] = node_edges_info_dict
                    self.node_path_reverse_dict[node_name] = node_edges_reverse_info_dict
                    
                    # number of paths in pog
                    total_sequences = self.count_path(mat)
                    self.node_pogs_cnt[node_name] = total_sequences
                    self.node_pogs[node_name] = mat
                    
                    # add nodes with only 1 path in pogs in the extant list
#                     if total_sequences == 1:
#                         self.extant_list.append(node_name)  # all extants
                    if total_sequences == 0:
                        print("ERROR:: There is no path in the POG")
                    
        return self.node_path_dict,self.node_path_reverse_dict,self.nodes,self.extant_list,self.node_pogs_cnt,\
                                                                                        self.node_pogs
    
    def node_type_info(self):
        ''' different node type information , to make it easier for MIP coding'''
        
        for node_name,node_edge_val in self.node_path_dict.items():
            self.node_type_dict[(node_name,'start')] = [0]
            self.node_type_dict[(node_name,'end')] = [self.nodes - 1]
            positions = self.nodes
            forward_edges = self.node_path_dict[node_name]
            backward_edges = self.node_path_reverse_dict[node_name]
            
            for n in range(1,positions - 1):   # do not include start / end positions
                if forward_edges.get(n) and backward_edges.get(n):
                    self.node_type_dict[(node_name,'fc_nodes')]   += [n]
                elif (forward_edges.get(n) and not backward_edges.get(n)):
                    self.node_type_dict[(node_name,'f_sc_nodes')] += [n]
                elif (not forward_edges.get(n) and backward_edges.get(n)):
                    self.node_type_dict[(node_name,'t_sc_nodes')] += [n] 
                else:
                    self.node_type_dict[(node_name,'uc_nodes')]   += [n]
        return self.node_type_dict
            
## testing
nwk_file_path = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/grasp_ancestors.nwk'
pogs_file     = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/pogs.json'
# p = Pogs(pogs_file,nwk_file_path)
# p.create_node_info_dict()
# p.create_neighbor_object()
# p.node_type_info()

# %% [markdown]
# ## MIP MODEL

# %%
''' MIP Model for preferred path with least parsimonous score 

CONSTRAINTS

EDGES - (ANCESTOR NODE ONLY)
1. possible_edge_constraint : edge is present and sum of all edges <= 1
2. na_edge_constraint       : edge is not present
3. edge_recon_constraint    : sum of the edges coming in is equal sum of edges going out ( not for start/end position)

POSITION - (ANCESTOR + EXTANTS)
1. extant_position_constraint     : fixed constraint if the position is present in extant
2. start_end_position_constraint  : start and end position contraint fixed and == 1
3. edge_from_constraint           : sum(of all going out edges) == position variable
4. edge_to_constraint             : sum(of all coming in edges) == position variable
5. unconnected_position_constraint: position in the node not connected to any other nodes

DIFFERENCE - (NEIGHBORS)
1. pos_diff_constraint : difference in each position betweeen node and its neighbors

PENALTY - (NEIGHBORS)
1. penalty_constraint  : penalty varaible constraint. it is 1 for every opening difference between positions.

'''

class PhyloTree:
    def __init__(self,nodes,sequence_length,neighbor_dict,node_from_edge_dict,folder_location\
                 ,extant_list,tree_name,position_type_dict,node_from_reverse_edge_dict):

        # Define the configuration  and decision variables for the tree
        self.nodes = nodes
        self.sequence_length = sequence_length
        self.neighbor_dict = neighbor_dict
        self.node_from_edge_dict = node_from_edge_dict
        self.folder_location = folder_location
        self.extant_list = extant_list
        self.tree_name = tree_name
        self.position_type_dict = position_type_dict
        self.node_from_reverse_edge_dict = node_from_reverse_edge_dict
        
        # MIP data structures
        self.edges = {}
        self.positions = {}
        self.penalty = {}
        self.diff = {}
        self.objective = []
        self.M = 999

        # 2 - create a new model
        self.m = gp.Model("PreferredPathSolve")
        
            
    def add_pos_var_constraints(self):     
        ''' add position, diff and penalty variables. add diff constraints'''
    
        # position constraints
        for node,node_edge_from_list in self.node_from_edge_dict.items():
            for pos_from in range(0,sequence_length):
                pos_id = (node,pos_from)
                pos = self.m.addVar(vtype=GRB.BINARY, name="n-%s-%s"%pos_id)
                self.positions[pos_id] = pos
                
                # special constraint for start and end node
                if pos_from == 0 or pos_from == self.sequence_length - 1:
                    self.m.addConstr(self.positions[pos_id] == 1,\
                                     name="start_end_position_constraint-%s-%s"%pos_id)

        for node,node_neighbor in self.neighbor_dict.items():
            for node_neighbor_item in node_neighbor:
                for pos in range(1,sequence_length - 1): # penalty start from 1st position only
                    
                    # penalty variables
                    pen_id = (node,node_neighbor_item,pos)
                    pen = self.m.addVar(vtype=GRB.BINARY, name='p-%s-%s-%s'%pen_id)
                    self.penalty[pen_id] = pen

                    # add position difference to the objective (not for start and end node)
                    node_pos_var = self.positions[(node,pos)]
                    node_neighbor_pos_var = self.positions[(node_neighbor_item,pos)]
                    diff_id = (node,node_neighbor_item,pos)
                    diff_pos = self.m.addVar(vtype=GRB.BINARY, name='d-%s-%s-%s'%diff_id)
                    self.diff[diff_id] = diff_pos

                    # abs difference constraint
                    self.m.addConstr( diff_pos <= node_pos_var + node_neighbor_pos_var,name=\
                                     "diff_constraint_1-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos >= node_pos_var - node_neighbor_pos_var,name=\
                                     "diff_constraint_2-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos >= node_neighbor_pos_var - node_pos_var,name=\
                                     "diff_constraint_3-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos <= 2 - node_neighbor_pos_var - node_pos_var,name=\
                                     "diff_constraint_4-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.objective.append(diff_pos)
        
        
    def add_pos_constraints_extants(self):
        ''' function to add constraints for extants to fix them '''

        for node in self.extant_list:
            extant_node_edges_forward = self.node_from_edge_dict[node]
            position_present = list(extant_node_edges_forward.keys())
            position_present.append(self.sequence_length - 1) # last position
            
            for pos_from in range(0,sequence_length):
                pos_id = (node,pos_from)
                if pos_from in position_present:
                    self.m.addConstr(self.positions[pos_id] == 1,\
                                     name="extant_position_constraint-%s-%s"%pos_id)
                else:
                    self.m.addConstr(self.positions[pos_id] == 0,\
                                     name="extant_position_constraint-%s-%s"%pos_id)    
             
    def penalty_constraints(self):
        ''' function to add penalty constraints '''
        
        for node,node_neighbor in self.neighbor_dict.items():
            for node_neighbor_item in node_neighbor:
                for pos in range(1,sequence_length - 1):  # no penalty for start and end
                    diff_id  = (node,node_neighbor_item,pos)
                    pen_id   = (node,node_neighbor_item,pos)
                    diff_var = self.diff[diff_id]
                    pen_var  = self.penalty[pen_id]
                    
                    if pos == 1: # penalty for first position is simple
                        self.m.addConstr(pen_var == diff_var,"penalty_constraint-%s-%s-%s"%\
                                         (node,node_neighbor_item,pos))
                    else:
                        pen_prev_id = (node,node_neighbor_item,pos - 1)
                        prev_pen_var =  self.penalty[pen_prev_id]
                        prev_diff_var = self.diff[pen_prev_id]
                        
                        self.m.addConstr(diff_var - prev_diff_var >= 1 - self.M * (1 - pen_var),\
                                         name="penalty_constraint_1-%s-%s-%s"%\
                                         (node,node_neighbor_item,pos))
                        self.m.addConstr(diff_var - prev_diff_var <= self.M * (pen_var),\
                                         name="penalty_constraint_2-%s-%s-%s"%\
                                         (node,node_neighbor_item,pos))
                    
                    # add penalty to the objective
                    self.objective.append(2 * pen_var)
                    
        
    def train(self,n_threads,time_out):
        # Params
        self.m.Params.Threads = n_threads
        self.m.Params.TimeLimit = time_out*60
        #self.m.Params.LogFile =  folder_location + 
        self.m.Params.LogToConsole = 0
        self.m.Params.Degenmoves=0
        
        # Optimize
        self.total_objective = sum([o for o in self.objective])
        self.m.setObjective(self.total_objective, GRB.MINIMIZE)
        self.m.update()
        
        self.m.write((self.folder_location + 'pf_mip_formulation_' + self.tree_name + '.lp'))
        self.m.optimize()
        
        # Is feasible?
        return self.m.SolCount > 0
    
    
    def get_info(self):
        info_all = {}
        info_all["objective"] = self.m.ObjVal
        info_all["bound"] = self.m.ObjBound
        info_all["gap"] = self.m.MIPGap
        info_all["is_optimal"] = (self.m.status == GRB.OPTIMAL)
        info_all["num_nodes"] = self.m.NodeCount
        info_all["num_vars"] = self.m.NumIntVars + self.m.NumBinVars

        if self.m.SolCount > 0:
            print("objective: %0.2f"%info_all["objective"])
            print("bound: %0.2f"%info_all["bound"])
            print("gap: %0.2f"%info_all["gap"])

        return info_all
    
    def get_solution(self):
        # get the path
        all_node_paths = {}
        for node,node_edge_from_list in self.node_from_edge_dict.items():
            preferred_path = []
            for pos_from in range(0,sequence_length):
                pos_id = (node,pos_from)
                preferred_path.append(int(self.positions[pos_id].X))
                
            all_node_paths[node] = preferred_path
            
        # get the differnece and penalty solution
        score_dict = {}
        overall_score = 0
        for node,node_neighbor in self.neighbor_dict.items():
            for node_neighbor_item in node_neighbor:
                total_score = 0
                for pos in range(1,sequence_length - 1): # penalty start from 1st position only
                    pen_id  = (node,node_neighbor_item,pos)
                    diff_id = (node,node_neighbor_item,pos)
                    
                    total_score = total_score + 2 * int(self.penalty[pen_id].X)
                    total_score = total_score + int(self.diff[diff_id].X)
                    
#                     if node == 'N1099' and node_neighbor_item == 'N1100':
#                         print("pen_id",pen_id)
#                         print("PENALTY",int(self.penalty[pen_id].X))
#                         print("DIFF",int(self.diff[diff_id].X))
#                         print("POSITION NODE",int(self.positions[(node,pos)].X))
#                         print("POSITION NODE NEIGHBOR",int(self.positions[(node_neighbor_item,pos)].X))
                        
                  
                #print("total_score between node {} and node-neighbor{} is {}"\
                                  #.format(node,node_neighbor_item,total_score)) 
                score_dict[(node,node_neighbor_item)] = total_score
                overall_score = overall_score + total_score
        print("overall_score",overall_score)
        return all_node_paths,score_dict

# %% [markdown]
# ## RUNNING MIP

# %%
# different trees

# TEST MIP Models for different trees

## sample tree
# nwk_file_path = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/grasp_ancestors.nwk'
# pogs_file     = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/sample_tree/pogs.json'
# tree_name = 'sample_tree'

## CYP2U - 165
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/pogs.json'
# tree_name = 'cyp2u_165'
# mip_ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_165/mip_grasp_ancestors.fa"

# ## CYP2U - 359
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_359/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_359/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_359/pogs.json'
# tree_name = 'cyp2u_359'

# ## CYP2U - 595
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_595/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_595/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/CYP2U_595/pogs.json'
# tree_name = 'cyp2u_595'

# ## DHAD - 585
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_585/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_585/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_585/pogs.json'
# tree_name = 'dhad_585'

# ## DHAD - 1612
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_1612/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_1612/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/DHAD_1612/pogs.json'
# tree_name = 'dhad_1612' 


# ## KARI - 1176
nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/KARI_1176/grasp_ancestors.nwk'
ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/KARI_1176/grasp_ancestors.fa"
pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/KARI_1176/pogs.json'
tree_name = 'kari_1176' 
mip_ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/KARI_1176/mip_grasp_ancestors.fa"


# ## GO - 399
# nwk_file_path       = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/GDH-GOx_399/grasp_ancestors.nwk'
# ancestor_fasta_file = "/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/GDH-GOx_399/grasp_ancestors.fa"
# pogs_file           = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/data/GDH-GOx_399/pogs.json'
# tree_name = 'go_399'

# %%
##### GET THE INPUT FOR MIP READY #####

folder_location = '/Users/sanjanatule/Documents/uq/Projects/PreferredPath/scripts/mip_files/'
TreePogs = Pogs(pogs_file,nwk_file_path)
node_from_edge_dict,node_from_reverse_edge_dict,sequence_length,extant_list,node_pogs_cnt,\
                                                        node_pogs = TreePogs.create_node_info_dict()
neighbor_dict = TreePogs.create_neighbor_object()
nodes = len(node_from_edge_dict)
node_type_dict = TreePogs.node_type_info()
print("TOTAL NODES::",nodes)
print("TOTAL POSITIONS:",sequence_length)
#print("EXTANT LIST:",extant_list)
# print("NEIGHBOR DICT:",neighbor_dict)
# print('NODE TYPE DICT:',node_type_dict)
# Out:
# TOTAL NODES:: 2351
# TOTAL POSITIONS: 513

# %%
#### RUN OPTIMISATION ####

start = time.time()
print("Start Time:",start)
n_threads = 1
time_out = 5
# initialise the class
PyTree = PhyloTree(nodes,sequence_length,neighbor_dict,node_from_edge_dict,folder_location\
                   ,extant_list,tree_name,node_type_dict,node_from_reverse_edge_dict)

PyTree.add_pos_var_constraints()
PyTree.add_pos_constraints_extants()
PyTree.penalty_constraints()

is_sat = PyTree.train(n_threads, time_out)
print("is_sat",is_sat)
total_time = ((time.time()-start))
print("-----------------------------")
print("Total time = %0.2f[m]"%total_time)
info = PyTree.get_info()
info["total_time"] = total_time
info["is_sat"] = is_sat
print("info",info)

if is_sat:
    all_node_paths,score_dict = PyTree.get_solution()
    #print("all_node_paths",all_node_paths)
else:
    print("Did not find any satisfactory solution to the model")
# Out:
# Start Time: 1662554392.795296
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-08-19
# self.diff <gurobi.Var *Awaiting Model Update*>
# Set parameter Threads to value 1
# Set parameter TimeLimit to value 300
# is_sat True
# -----------------------------
# Total time = 543.72[m]
# objective: 5144.00
# bound: 5144.00
# gap: 0.00
# info {'objective': 5144.0, 'bound': 5144.0, 'gap': 0.0, 'is_optimal': True, 'num_nodes': 1.0, 'num_vars': 7215526, 'total_time': 543.7211830615997, 'is_sat': True}
# pen_id ('N1099', 'N1100', 1)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 2)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 3)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 4)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 5)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 6)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 7)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 8)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 9)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 10)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 11)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 12)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 13)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 14)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 15)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 16)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 17)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 18)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 19)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 20)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 21)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 22)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 23)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 24)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 25)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 26)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 27)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 28)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 29)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 30)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 31)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 32)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 33)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 34)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 35)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 36)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 37)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 38)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 39)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 40)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 41)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 42)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 43)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 44)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 45)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 46)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 47)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 48)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 49)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 50)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 51)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 52)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 53)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 54)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 55)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 56)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 57)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 58)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 59)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 60)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 61)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 62)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 63)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 64)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 65)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 66)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 67)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 68)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 69)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 70)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 71)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 72)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 73)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 74)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 75)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 76)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 77)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 78)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 79)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 80)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 81)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 82)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 83)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 84)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 85)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 86)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 87)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 88)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 89)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 90)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 91)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 92)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 93)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 94)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 95)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 96)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 97)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 98)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 99)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 100)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 101)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 102)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 103)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 104)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 105)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 106)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 107)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 108)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 109)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 110)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 111)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 112)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 113)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 114)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 115)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 116)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 117)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 118)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 119)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 120)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 121)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 122)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 123)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 124)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 125)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 126)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 127)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 128)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 129)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 130)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 131)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 132)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 133)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 134)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 135)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 136)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 137)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 138)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 139)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 140)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 141)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 142)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 143)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 144)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 145)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 146)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 147)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 148)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 149)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 150)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 151)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 152)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 153)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 154)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 155)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 156)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 157)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 158)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 159)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 160)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 161)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 162)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 163)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 164)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 165)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 166)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 167)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 168)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 169)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 170)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 171)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 172)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 173)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 174)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 175)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 176)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 177)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 178)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 179)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 180)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 181)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 182)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 183)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 184)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 185)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 186)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 187)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 188)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 189)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 190)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 191)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 192)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 193)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 194)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 195)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 196)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 197)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 198)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 199)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 200)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 201)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 202)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 203)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 204)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 205)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 206)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 207)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 208)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 209)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 210)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 211)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 212)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 213)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 214)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 215)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 216)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 217)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 218)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 219)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 220)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 221)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 222)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 223)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 224)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 225)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 226)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 227)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 228)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 229)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 230)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 231)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 232)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 233)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 234)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 235)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 236)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 237)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 238)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 239)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 240)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 241)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 242)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 243)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 244)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 245)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 246)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 247)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 248)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 249)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 250)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 251)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 252)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 253)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 254)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 255)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 256)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 257)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 258)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 259)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 260)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 261)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 262)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 263)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 264)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 265)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 266)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 267)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 268)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 269)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 270)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 271)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 272)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 273)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 274)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 275)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 276)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 277)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 278)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 279)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 280)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 281)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 282)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 283)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 284)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 285)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 286)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 287)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 288)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 289)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 290)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 291)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 292)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 293)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 294)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 295)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 296)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 297)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 298)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 299)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 300)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 301)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 302)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 303)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 304)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 305)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 306)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 307)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 308)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 309)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 310)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 311)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 312)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 313)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 314)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 315)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 316)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 317)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 318)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 319)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 320)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 321)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 322)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 323)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 324)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 325)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 326)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 327)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 328)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 329)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 330)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 331)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 332)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 333)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 334)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 335)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 336)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 337)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 338)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 339)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 340)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 341)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 342)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 343)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 344)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 345)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 346)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 347)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 348)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 349)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 350)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 351)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 352)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 353)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 354)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 355)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 356)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 357)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 358)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 359)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 360)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 361)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 362)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 363)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 364)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 365)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 366)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 367)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 368)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 369)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 370)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 371)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 372)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 373)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 374)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 375)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 376)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 377)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 378)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 379)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 380)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 381)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 382)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 383)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 384)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 385)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 386)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 387)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 388)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 389)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 390)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 391)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 392)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 393)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 394)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 395)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 396)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 397)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 398)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 399)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 400)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 401)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 402)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 403)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 404)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 405)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 406)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 407)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 408)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 409)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 410)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 411)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 412)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 413)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 414)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 415)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 416)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 417)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 418)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 419)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 420)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 421)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 422)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 423)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 424)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 425)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 426)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 427)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 428)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 429)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 430)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 431)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 432)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 433)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 434)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 435)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 436)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 437)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 438)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 439)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 440)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 441)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 442)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 443)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 444)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 445)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 446)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 447)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 448)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 449)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 450)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 451)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 452)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 453)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 454)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 455)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 456)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 457)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 458)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 459)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 460)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 461)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 462)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 463)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 464)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 465)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 466)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 467)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 468)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 469)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 470)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 471)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 472)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 473)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 474)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 475)
# PENALTY 0
# DIFF 0
# POSITION NODE 1
# POSITION NODE NEIGHBOR 1
# pen_id ('N1099', 'N1100', 476)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 477)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 478)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 479)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 480)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 481)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 482)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 483)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 484)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 485)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 486)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 487)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 488)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 489)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 490)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 491)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 492)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 493)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 494)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 495)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 496)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 497)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 498)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 499)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 500)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 501)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 502)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 503)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 504)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 505)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 506)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 507)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 508)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 509)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 510)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# pen_id ('N1099', 'N1100', 511)
# PENALTY 0
# DIFF 0
# POSITION NODE 0
# POSITION NODE NEIGHBOR 0
# overall_score 5144

# %%
# convert output file to FASTA file
with open(mip_ancestor_fasta_file,mode='w') as fout:
    for node_name,sequence in all_node_paths.items():
        fout.write('>' + str(node_name) + '\n')
        sequence_str = ''.join([str(s) for s in sequence])
        fout.write(str(sequence_str) + '\n')

# %% [markdown]
# ## CHECKING THE MIP SOLUTION

# %%
''' functions for use in checking solution '''

''' get the sequence string after removing commas and start/end node'''
def get_sequence_string(preferred_path):
    pf_str = ''
    for p in preferred_path:
        pf_str = pf_str + str(p)

    # remove first and last path
    pf_str = pf_str[1:-1]
    return pf_str

''' verify the score given by mip '''
def sequence_distance_score(str1,str2):
    dis = 0
    prev_dis = 0
    
    for i in range(0,len(str1)):
        if str1[i] != str2[i]:  # not matching
            if prev_dis == 0:   # previous unmatched
                dis += 3
                prev_dis = 1
            else:
                dis += 1
        else:
            prev_dis = 0
    return dis

def sequence_distance_score_1(str1,str2):
    dis = 0
    prev_dis = 0
    
    for i in range(0,len(str1)):
        if str1[i] != str2[i]:  # not matching
            dis += 1
    return dis

''' Check if path is valid path and not broken '''
def next_one(from_pos,path,seq_length):
    if from_pos == seq_length - 1:  # end pos
        return from_pos
    for p_ind in range(from_pos + 1,seq_length):
        if path[p_ind] == 1:
            return p_ind
        
def check_path_complete(pog_mat,path,seq_length):
    valid = 0
    # first position
    from_p = 0
    to_p = next_one(from_p,path,seq_length)
    
    while(1):
        if pog_mat[from_p][to_p] == 1:
            from_p = to_p
            to_p   = next_one(from_p,path,seq_length) # next position with 1
            #print('to_p',to_p)
            
            if to_p == seq_length - 1: # end position
                valid = 1
                break
        else:
            valid = 0
            break
    return valid

# test
# pog_mat = np.array([(0,0,1),(0,0,0),(0,0,0)])
# path = [1,0,1]
# seq_length = 3
# check_path_complete(pog_mat,path,seq_length)

# %%
''' 1 - check whether path is complete and fixed path are not changed '''
# 1 -- check output from mip 
def check_mip_output_node_changes(grasp_fasta_file,all_node_paths,extant_list,node_pogs,node_pogs_cnt):
    
    sequences_info = FastaFile(grasp_fasta_file)
    total_node_change = 0

    for node_name,preferred_path in all_node_paths.items(): # mip path
        grasp_output_seq = sequences_info.fetch(node_name)

        # convert into 1/0
        grasp_output_seq =  re.sub('[a-zA-Z]', '1', grasp_output_seq)
        grasp_output_seq = grasp_output_seq.replace('-','0')
        #print('grasp_output_seq',grasp_output_seq)

        # compare with mip output
        pf_str = ''
        for p in preferred_path:
            pf_str = pf_str + str(p)

        # remove first and last path
        pf_str = pf_str[1:-1]

        #print("preferred_path",pf_str)
        if grasp_output_seq != pf_str:
            total_node_change += 1

            if node_name in extant_list:
                print("Node::",node_name)
                print("ERROR: path is different for an extant.Should not change.")

    print("Total nodes changed",total_node_change)

check_mip_output_node_changes(ancestor_fasta_file,all_node_paths,extant_list,node_pogs,node_pogs_cnt)
# Out:
# Total nodes changed 186

# %%
''' 2 - compare/check the score function between heuristic and mip method '''
### 2 - check score
def check_score(score_dict,neighbor_dict):
    # compare score with hueristics solution
    for node,node_neighbor_list in neighbor_dict.items():
        node_sequence = get_sequence_string(all_node_paths[node])
        for nn in node_neighbor_list:
            nn_sequence = get_sequence_string(all_node_paths[nn])
            # calculate score between the nodes
            diff_score = sequence_distance_score(node_sequence,nn_sequence)
            # compare with mip score
            mip_score = score_dict[(node,nn)]
            if diff_score != mip_score:
                print('node',node)
                print("node neighbor",nn)
                print("diff_score",diff_score)
                print("mip_score",mip_score)
                print("ERROR: Score is different")
                print("node sequence",node_sequence)
                print("nn sequence",nn_sequence)
check_score(score_dict,neighbor_dict)
