# %%
''' Run MIP for indel inference '''

# libraries
import gurobipy as gp
from gurobipy import abs_,quicksum
from gurobipy import GRB
import time
import json
from collections import defaultdict
import numpy as np
import torch
from torch.utils.data import Dataset
import pickle

# %%
class PhyloTreeMIP:
    def __init__(self,extant_data,ancestor_data,tree_name,neighbor_dict,mip_ancestor_fasta_file,mip_model_file):

        # Define the configuration  and decision variables for the tree
        self.extant_data = extant_data
        self.ancestor_data = ancestor_data
        self.tree_name = tree_name
        self.sequence_length = len(list(self.extant_data.values())[0])
        self.neighbor_dict = neighbor_dict
        self.objective = []
        self.mip_ancestor_fasta_file = mip_ancestor_fasta_file
        self.all_node_paths = {}
        self.mip_model_file = mip_model_file
        self.sequence_range = range(1,self.sequence_length-1)
        self.extant_list = self.extant_data.keys()
        self.ancestor_list = self.ancestor_data[0]

        # MIP data structures
        self.ancestorsequence = {}
        self.edges = {}
        self.penalty = {}
        self.diff = {}
        self.objective = []

        # 2 - create a new model
        self.m = gp.Model("PreferredPathSolve")

    def add_pos_constraints_ancestors(self):
        ''' function to add constraints for positions in ancestors  '''
        
        # V - create variable for each ancestor sequence
        for ancestor in self.ancestor_list:
            an = self.m.addVars(self.sequence_range,vtype=GRB.BINARY, name="an-%s"%ancestor)
            self.ancestorsequence[ancestor] = an
            

    def add_edge_constraints_ancestors(self):
        ''' function to add constraints for edges in ancestors  '''

        ancestor_fwd_edges  = self.ancestor_data[1]
        ancestor_bkwd_edges = self.ancestor_data[2]
        ancestor_node_type  = self.ancestor_data[3]

        # for each ancestor
        for ancestor in self.ancestor_list:

            # START NODES
            for fwd_back_pos in ancestor_node_type.get(('ANCESTOR','start')):

                all_edges_from_pos = []
                for pos_to in ancestor_fwd_edges[fwd_back_pos]:
                    edge_id = (ancestor,fwd_back_pos,pos_to)
                    # V - var for each edge from start node
                    e = self.m.addVar(vtype=GRB.BINARY, name='e-%s-%s-%s'%edge_id)
                    self.edges[edge_id] = e
                    all_edges_from_pos.append(e)

                # C - 1 edge has to be can be used
                self.m.addConstr(quicksum(all_edges_from_pos) == 1,\
                                            name = "ancestor_start_node_recon_constraint-%s"%ancestor)

            # DEAD NODES
            if ancestor_node_type.get(('ANCESTOR','dead_pos')) :
                for fwd_back_pos in ancestor_node_type.get(('ANCESTOR','dead_pos')):
                    pos_id = (ancestor,fwd_back_pos)
                    # C - constraint for dead pos to 0 as they cannot find complete path
                    self.m.addConstr(self.ancestorsequence[ancestor][fwd_back_pos] == 0,\
                                                name = "ancestor_dead_pos-%s-%s"%pos_id)

            # FULLY CONNECTED NODES
            for fwd_back_pos in ancestor_node_type.get(('ANCESTOR','fwd_back_pos')):
                
                pos_id = (ancestor,fwd_back_pos)
                # C - edges going out of the node
                all_edges_from_pos = []
                for pos_to in ancestor_fwd_edges[fwd_back_pos]:
                    edge_id = (ancestor,fwd_back_pos,pos_to)
                    # V - var for each edge going from the node
                    e = self.m.addVar(vtype=GRB.BINARY, name='e-%s-%s-%s'%edge_id)
                    self.edges[edge_id] = e
                    all_edges_from_pos.append(e)

                # C - edges coming in into the node
                edges_coming_in_list = []
                for edges_coming_in_item in ancestor_bkwd_edges[fwd_back_pos]:
                    edge_to_id = (ancestor,edges_coming_in_item,fwd_back_pos)
                    edges_coming_in_list.append(self.edges[edge_to_id])
                
                # C - sum(edges) = position
                self.m.addConstr(quicksum(all_edges_from_pos) == self.ancestorsequence[ancestor][fwd_back_pos],\
                                            name="ancestor_edge_node_recon_constraint1-%s-%s"%pos_id)
                # C - sum(edges) = position
                self.m.addConstr(quicksum(edges_coming_in_list) == self.ancestorsequence[ancestor][fwd_back_pos],\
                                            name="ancestor_edge_node_recon_constraint2-%s-%s"%pos_id)

            # END NODES
            for fwd_back_pos in ancestor_node_type.get(('ANCESTOR','end')):

                all_edges_to_pos = []
                for pos_from in ancestor_bkwd_edges[fwd_back_pos]:
                    edge_id = (ancestor,pos_from,fwd_back_pos)
                    all_edges_to_pos.append(self.edges[edge_id])
                        

                # C - sum(edges) = position
                self.m.addConstr(quicksum(all_edges_to_pos) == 1,\
                                             name = "ancestor_end_node_recon_constraint-%s"%ancestor)
                    

    # penalty constraint
    def add_penalty_constraint(self):
        ''' function to add penalty constraints for whole tree  '''
        
        # difference constraints
        for node,node_neighbor in self.neighbor_dict.items():
            for node_neighbor_item in node_neighbor:

                # V - add position difference variable
                node_pos_var = self.ancestorsequence[node]

                # check if it is a extant node or not
                if node_neighbor_item in self.extant_list:
                    node_neighbor_pos_var = [int(i) for i in self.extant_data[node_neighbor_item]]
                else:
                    node_neighbor_pos_var = self.ancestorsequence[node_neighbor_item]

                # V - create variables
                nn_pair               = (node,node_neighbor_item)
                diff_pos              = self.m.addVars(self.sequence_range,vtype=GRB.BINARY, \
                                                name='d-%s-%s'%nn_pair)
                pen                   = self.m.addVars(self.sequence_range,vtype=GRB.BINARY, \
                                                name='pe-%s-%s'%nn_pair)
                self.diff[nn_pair]    = diff_pos
                self.penalty[nn_pair] = pen
                
                
                for pos in range(1,self.sequence_length - 1):

                    # C - Abs constraints
                    self.m.addConstr( diff_pos[pos] <= node_pos_var[pos] + node_neighbor_pos_var[pos],name=\
                                     "diff_constraint_1-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos[pos] >= node_pos_var[pos] - node_neighbor_pos_var[pos],name=\
                                     "diff_constraint_2-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos[pos] >= node_neighbor_pos_var[pos] - node_pos_var[pos],name=\
                                     "diff_constraint_3-%s-%s-%s"%(node,node_neighbor_item,pos))
                    self.m.addConstr( diff_pos[pos] <= 2 - node_neighbor_pos_var[pos] - node_pos_var[pos],name=\
                                     "diff_constraint_4-%s-%s-%s"%(node,node_neighbor_item,pos))
                    
                    # C - penalty constraits
                    if pos == 1: # penalty for first position is simple
                        self.m.addConstr(pen[pos] == diff_pos[pos],"penalty_constraint-%s-%s-%s"%\
                                         (node,node_neighbor_item,pos))
                    else:
                        self.m.addConstr(pen[pos] >= diff_pos[pos] - diff_pos[pos-1])
                        
                    # O - add difference to the objective
                    self.objective.append(diff_pos[pos])

                    # O - add penalty to the objective
                    self.objective.append(2 * pen[pos])                    
                    

    def train(self,n_threads,time_out):
        # Params
        self.m.Params.Threads = n_threads
        self.m.Params.TimeLimit = time_out*60
        self.m.Params.LogToConsole = 0
        self.m.Params.Degenmoves=0
        self.m.Params.Method = 1
        self.m.Params.LogFile = "mip_model.log"

        # Optimize
        self.total_objective = quicksum(self.objective)
        self.m.setObjective(self.total_objective, GRB.MINIMIZE)
        self.m.update()

        self.m.write(('mip_model_' + self.tree_name + '.lp'))
        self.m.optimize()

        #Is feasible?
        return self.m.SolCount > 0

    def get_info(self):
        info_all = {}
        info_all["objective"] = self.m.ObjVal
        info_all["bound"] = self.m.ObjBound
        info_all["gap"] = self.m.MIPGap
        info_all["is_optimal"] = (self.m.status == GRB.OPTIMAL)
        info_all["num_nodes"] = self.m.NodeCount
        info_all["num_vars"] = self.m.numVars
        if self.m.SolCount > 0:
            print("objective: %0.2f"%info_all["objective"])
            print("bound: %0.2f"%info_all["bound"])
            print("gap: %0.2f"%info_all["gap"])

        return info_all
    
    def output_fasta(self,all_node_paths):
        # convert output file to FASTA file
        with open(self.mip_ancestor_fasta_file,mode='w') as fout:
            for node_name,sequence in all_node_paths.items():
                fout.write('>' + str(node_name) + '\n')
                sequence_str = ''.join([str(s) for s in sequence])
                fout.write(str(sequence_str) + '\n')
    
    def get_solution(self):
        # get the path for extants - should be same as the input
        all_node_paths = {}
        
        for sequence_name,preferred_path in self.extant_data.items():
            all_node_paths[sequence_name] = preferred_path
        
        # get the path for ancestor
        for ancestor in self.ancestor_data[0]:
            preferred_path = []
            preferred_path.append('1') # start position
            for pos in range(1,self.sequence_length-1):
                preferred_path.append(str(int(self.ancestorsequence[ancestor][pos].X)))
            preferred_path.append('1') # end position
            
            all_node_paths[ancestor] = "".join(preferred_path)
            
        # get the differnece and penalty solution
        score_dict = {}
        overall_score = 0
        for node,node_neighbor in self.neighbor_dict.items():
            for node_neighbor_item in node_neighbor:
                total_score_1 = 0
                total_score_2 = 0
                pen_id  = (node,node_neighbor_item)
                diff_id = (node,node_neighbor_item)
                
                for pos in range(1,self.sequence_length - 1): # penalty start from 1st position only
                    
                    total_score_1 = total_score_1 + 2 * int(self.penalty[pen_id][pos].X)
                    total_score_2 = total_score_2 + int(self.diff[diff_id][pos].X)
#                     print(f"pos-{pos}")
#                     print(2 * int(self.penalty[pen_id][pos].X))
#                     print(int(self.diff[diff_id][pos].X))
                    
#                     try:
#                         print(int(self.ancestorsequence[node][pos].X))
#                     except:
#                         print(int(self.extant_data[node][pos]))
#                     try:
#                         print(int(self.ancestorsequence[node_neighbor_item][pos].X)) 
#                     except:
#                         print(int(self.extant_data[node_neighbor_item][pos]))
                
                print(f"Sequence for node {node} is {all_node_paths[node]}")
                print(f"Sequence for node {node_neighbor_item} is {all_node_paths[node_neighbor_item]}")
                print(f"Difference Score between {node} and {node_neighbor_item} is {total_score_2}")
                print(f"Penalty Score between {node} and {node_neighbor_item} is {total_score_1}")
                print(f"Total score is {total_score_1 + total_score_2}")
                
                score_dict[(node,node_neighbor_item)] = total_score_1 + total_score_2
                overall_score = overall_score + total_score_1 + total_score_2
                
        return all_node_paths ,score_dict, overall_score
        

def main():
    folder_location         = '/Users/sanjanatule/Documents/uq/Projects/MIPIndel/data/'
    #folder_location         = '/media/WorkingSpace/Share/mipindel/data/'

    ## Sample tree 1
    tree_name               =   'CYP2U_165' #'st1' #'DHAD_1612' #'Anthony' #'DHAD_1612' #  #'CYP2U_359'#'CYP2U_165'
    mip_ancestor_fasta_file = folder_location + tree_name + '/mip_ancestor_indel.fasta'
    mip_model_file = folder_location + tree_name + '/mip_model.lp'

    # read input Dataset
    with open(folder_location + tree_name + '/ancestor_info.pkl', 'rb') as f:
        ancestor_data = pickle.load(f)

    with open(folder_location + tree_name + '/neighbor_dict.pkl', 'rb') as f:
        neighbor_dict = pickle.load(f)

    with open(folder_location + tree_name + '/extant_data.pkl', 'rb') as f:
        extant_data = pickle.load(f)


    # Run MIP
    start = time.time()
    print("Start Time:",start)

    # initialise the class
    PyTree = PhyloTreeMIP(extant_data,ancestor_data,tree_name,neighbor_dict,mip_ancestor_fasta_file,mip_model_file)

    # variable position constraints for ancestors
    print("Adding Ancestor Constraints")
    PyTree.add_pos_constraints_ancestors()
    # edge constraints for ancestors
    print("Adding Edges Constraints")
    #PyTree.add_edge_constraints_ancestors()
    # position difference constraints
    print("Adding Penalty Constraints")
    
    PyTree.add_penalty_constraint()

    print('Training MIP Model')
    
    total_time = ((time.time()-start)/60)
    print("-----------------------------")
    print("Total time to create model = %0.2f[mins]"%total_time)
    
    start = time.time()
    print("Start Time:",start)
    n_threads = 1
    time_out = 60 # 1 hour
    
    is_sat = PyTree.train(n_threads, time_out)
    print("is_sat",is_sat)
    total_time = ((time.time()-start)/60)
    print("-----------------------------")
    print("Total time to solve model= %0.2f[mins]"%total_time)
    info = PyTree.get_info()
    info["total_time"] = total_time
    info["is_sat"] = is_sat
    
    print("info",info)

    if is_sat:
        all_node_paths,score_dict, overall_score = PyTree.get_solution()
#         print(all_node_paths)
#         print(score_dict)
#         print(overall_score)
        PyTree.output_fasta(all_node_paths)
    else:
        print("Did not find any satisfactory solution to the model")

# %%
main()
# Out:
# Start Time: 1684506801.140521
# Adding Ancestor Constraints
# Adding Edges Constraints
# Adding Penalty Constraints
# Training MIP Model
# -----------------------------
# Total time to create model = 0.18[mins]
# Start Time: 1684506811.647425
# Set parameter Threads to value 1
# Set parameter TimeLimit to value 3600
# is_sat True
# -----------------------------
# Total time to solve model= 0.27[mins]
# objective: 3134.00
# bound: 3134.00
# gap: 0.00
# info {'objective': 3134.0, 'bound': 3134.0, 'gap': 0.0, 'is_optimal': True, 'num_nodes': 1.0, 'num_vars': 512500, 'total_time': 0.27403958241144816, 'is_sat': True}
# Sequence for node NODE_0 is ...
# Sequence for node NODE_1 is ...
# Difference Score between NODE_0 and NODE_1 is 1
# Penalty Score between NODE_0 and NODE_1 is 2
# Total score is 3
# Sequence for node NODE_0 is ...
# Sequence for node XP_020383892.1 is ...
# Difference Score between NODE_0 and XP_020383892.1 is 18
# Penalty Score between NODE_0 and XP_020383892.1 is 10
# Total score is 28
# Sequence for node NODE_1 is ...
# Sequence for node NODE_2 is ...
# Difference Score between NODE_1 and NODE_2 is 10
# Penalty Score between NODE_1 and NODE_2 is 12
# Total score is 22
# Sequence for node NODE_1 is ...
# Sequence for node NODE_3 is ...
# Difference Score between NODE_1 and NODE_3 is 2
# Penalty Score between NODE_1 and NODE_3 is 4
# Total score is 6
# Sequence for node NODE_2 is ...
# Sequence for node XP_006629927.2 is ...
# Difference Score between NODE_2 and XP_006629927.2 is 11
# Penalty Score between NODE_2 and XP_006629927.2 is 12
# Total score is 23
# Sequence for node NODE_2 is ...
# Sequence for node NODE_4 is ...
# Difference Score between NODE_2 and NODE_4 is 0
# Penalty Score between NODE_2 and NODE_4 is 0
# Total score is 0
# Sequence for node NODE_3 is ...
# Sequence for node NODE_5 is ...
# Difference Score between NODE_3 and NODE_5 is 2
# Penalty Score between NODE_3 and NODE_5 is 4
# Total score is 6
# Sequence for node NODE_3 is ...
# Sequence for node NODE_6 is ...
# Difference Score between NODE_3 and NODE_6 is 6
# Penalty Score between NODE_3 and NODE_6 is 4
# Total score is 10
# Sequence for node NODE_4 is ...
# Sequence for node XP_018611667.1 is ...
# Difference Score between NODE_4 and XP_018611667.1 is 7
# Penalty Score between NODE_4 and XP_018611667.1 is 10
# Total score is 17
# Sequence for node NODE_4 is ...
# Sequence for node NODE_7 is ...
# Difference Score between NODE_4 and NODE_7 is 4
# Penalty Score between NODE_4 and NODE_7 is 6
# Total score is 10
# Sequence for node NODE_5 is ...
# Sequence for node NODE_8 is ...
# Difference Score between NODE_5 and NODE_8 is 14
# Penalty Score between NODE_5 and NODE_8 is 10
# Total score is 24
# Sequence for node NODE_5 is ...
# Sequence for node ARO89866.1 is ...
# Difference Score between NODE_5 and ARO89866.1 is 7
# Penalty Score between NODE_5 and ARO89866.1 is 6
# Total score is 13
# Sequence for node NODE_6 is ...
# Sequence for node NODE_9 is ...
# Difference Score between NODE_6 and NODE_9 is 7
# Penalty Score between NODE_6 and NODE_9 is 6
# Total score is 13
# Sequence for node NODE_6 is ...
# Sequence for node NODE_10 is ...
# Difference Score between NODE_6 and NODE_10 is 10
# Penalty Score between NODE_6 and NODE_10 is 10
# Total score is 20
# Sequence for node NODE_7 is ...
# Sequence for node NODE_11 is ...
# Difference Score between NODE_7 and NODE_11 is 1
# Penalty Score between NODE_7 and NODE_11 is 2
# Total score is 3
# Sequence for node NODE_7 is ...
# Sequence for node NODE_12 is ...
# Difference Score between NODE_7 and NODE_12 is 1
# Penalty Score between NODE_7 and NODE_12 is 2
# Total score is 3
# Sequence for node NODE_8 is ...
# Sequence for node NODE_13 is ...
# Difference Score between NODE_8 and NODE_13 is 1
# Penalty Score between NODE_8 and NODE_13 is 2
# Total score is 3
# Sequence for node NODE_8 is ...
# Sequence for node XP_018409984.1 is ...
# Difference Score between NODE_8 and XP_018409984.1 is 0
# Penalty Score between NODE_8 and XP_018409984.1 is 0
# Total score is 0
# Sequence for node NODE_9 is ...
# Sequence for node NODE_14 is ...
# Difference Score between NODE_9 and NODE_14 is 0
# Penalty Score between NODE_9 and NODE_14 is 0
# Total score is 0
# Sequence for node NODE_9 is ...
# Sequence for node NODE_15 is ...
# Difference Score between NODE_9 and NODE_15 is 3
# Penalty Score between NODE_9 and NODE_15 is 2
# Total score is 5
# Sequence for node NODE_10 is ...
# Sequence for node NODE_16 is ...
# Difference Score between NODE_10 and NODE_16 is 13
# Penalty Score between NODE_10 and NODE_16 is 10
# Total score is 23
# Sequence for node NODE_10 is ...
# Sequence for node NODE_17 is ...
# Difference Score between NODE_10 and NODE_17 is 2
# Penalty Score between NODE_10 and NODE_17 is 4
# Total score is 6
# Sequence for node NODE_11 is ...
# Sequence for node XP_012687241.1 is ...
# Difference Score between NODE_11 and XP_012687241.1 is 0
# Penalty Score between NODE_11 and XP_012687241.1 is 0
# Total score is 0
# Sequence for node NODE_11 is ...
# Sequence for node NODE_18 is ...
# Difference Score between NODE_11 and NODE_18 is 0
# Penalty Score between NODE_11 and NODE_18 is 0
# Total score is 0
# Sequence for node NODE_12 is ...
# Sequence for node NODE_19 is ...
# Difference Score between NODE_12 and NODE_19 is 1
# Penalty Score between NODE_12 and NODE_19 is 2
# Total score is 3
# Sequence for node NODE_12 is ...
# Sequence for node NODE_20 is ...
# Difference Score between NODE_12 and NODE_20 is 5
# Penalty Score between NODE_12 and NODE_20 is 2
# Total score is 7
# Sequence for node NODE_13 is ...
# Sequence for node XP_018106696.1 is ...
# Difference Score between NODE_13 and XP_018106696.1 is 0
# Penalty Score between NODE_13 and XP_018106696.1 is 0
# Total score is 0
# Sequence for node NODE_13 is ...
# Sequence for node NP_001106471.1 is ...
# Difference Score between NODE_13 and NP_001106471.1 is 0
# Penalty Score between NODE_13 and NP_001106471.1 is 0
# Total score is 0
# Sequence for node NODE_14 is ...
# Sequence for node XP_015281737.1 is ...
# Difference Score between NODE_14 and XP_015281737.1 is 24
# Penalty Score between NODE_14 and XP_015281737.1 is 8
# Total score is 32
# Sequence for node NODE_14 is ...
# Sequence for node NODE_21 is ...
# Difference Score between NODE_14 and NODE_21 is 20
# Penalty Score between NODE_14 and NODE_21 is 8
# Total score is 28
# Sequence for node NODE_15 is ...
# Sequence for node XP_005287999.1 is ...
# Difference Score between NODE_15 and XP_005287999.1 is 1
# Penalty Score between NODE_15 and XP_005287999.1 is 2
# Total score is 3
# Sequence for node NODE_15 is ...
# Sequence for node NODE_22 is ...
# Difference Score between NODE_15 and NODE_22 is 13
# Penalty Score between NODE_15 and NODE_22 is 6
# Total score is 19
# Sequence for node NODE_16 is ...
# Sequence for node NODE_23 is ...
# Difference Score between NODE_16 and NODE_23 is 0
# Penalty Score between NODE_16 and NODE_23 is 0
# Total score is 0
# Sequence for node NODE_16 is ...
# Sequence for node XP_001366063.1 is ...
# Difference Score between NODE_16 and XP_001366063.1 is 2
# Penalty Score between NODE_16 and XP_001366063.1 is 2
# Total score is 4
# Sequence for node NODE_17 is ...
# Sequence for node XP_006881166.1 is ...
# Difference Score between NODE_17 and XP_006881166.1 is 0
# Penalty Score between NODE_17 and XP_006881166.1 is 0
# Total score is 0
# Sequence for node NODE_17 is ...
# Sequence for node NODE_24 is ...
# Difference Score between NODE_17 and NODE_24 is 0
# Penalty Score between NODE_17 and NODE_24 is 0
# Total score is 0
# Sequence for node NODE_18 is ...
# Sequence for node NODE_25 is ...
# Difference Score between NODE_18 and NODE_25 is 4
# Penalty Score between NODE_18 and NODE_25 is 6
# Total score is 10
# Sequence for node NODE_18 is ...
# Sequence for node NODE_26 is ...
# Difference Score between NODE_18 and NODE_26 is 2
# Penalty Score between NODE_18 and NODE_26 is 2
# Total score is 4
# Sequence for node NODE_19 is ...
# Sequence for node XP_010886716.1 is ...
# Difference Score between NODE_19 and XP_010886716.1 is 2
# Penalty Score between NODE_19 and XP_010886716.1 is 2
# Total score is 4
# Sequence for node NODE_19 is ...
# Sequence for node NODE_27 is ...
# Difference Score between NODE_19 and NODE_27 is 2
# Penalty Score between NODE_19 and NODE_27 is 2
# Total score is 4
# Sequence for node NODE_20 is ...
# Sequence for node XP_019717376.1 is ...
# Difference Score between NODE_20 and XP_019717376.1 is 12
# Penalty Score between NODE_20 and XP_019717376.1 is 8
# Total score is 20
# Sequence for node NODE_20 is ...
# Sequence for node NODE_28 is ...
# Difference Score between NODE_20 and NODE_28 is 0
# Penalty Score between NODE_20 and NODE_28 is 0
# Total score is 0
# Sequence for node NODE_21 is ...
# Sequence for node NODE_29 is ...
# Difference Score between NODE_21 and NODE_29 is 0
# Penalty Score between NODE_21 and NODE_29 is 0
# Total score is 0
# Sequence for node NODE_21 is ...
# Sequence for node XP_003226556.2 is ...
# Difference Score between NODE_21 and XP_003226556.2 is 44
# Penalty Score between NODE_21 and XP_003226556.2 is 8
# Total score is 52
# Sequence for node NODE_22 is ...
# Sequence for node NODE_30 is ...
# Difference Score between NODE_22 and NODE_30 is 4
# Penalty Score between NODE_22 and NODE_30 is 4
# Total score is 8
# Sequence for node NODE_22 is ...
# Sequence for node NODE_31 is ...
# Difference Score between NODE_22 and NODE_31 is 6
# Penalty Score between NODE_22 and NODE_31 is 6
# Total score is 12
# Sequence for node NODE_23 is ...
# Sequence for node XP_023361506.1 is ...
# Difference Score between NODE_23 and XP_023361506.1 is 5
# Penalty Score between NODE_23 and XP_023361506.1 is 6
# Total score is 11
# Sequence for node NODE_23 is ...
# Sequence for node XP_020857009.1 is ...
# Difference Score between NODE_23 and XP_020857009.1 is 1
# Penalty Score between NODE_23 and XP_020857009.1 is 2
# Total score is 3
# Sequence for node NODE_24 is ...
# Sequence for node XP_004703511.1 is ...
# Difference Score between NODE_24 and XP_004703511.1 is 71
# Penalty Score between NODE_24 and XP_004703511.1 is 22
# Total score is 93
# Sequence for node NODE_24 is ...
# Sequence for node NODE_32 is ...
# Difference Score between NODE_24 and NODE_32 is 0
# Penalty Score between NODE_24 and NODE_32 is 0
# Total score is 0
# Sequence for node NODE_25 is ...
# Sequence for node XP_017318806.1 is ...
# Difference Score between NODE_25 and XP_017318806.1 is 5
# Penalty Score between NODE_25 and XP_017318806.1 is 6
# Total score is 11
# Sequence for node NODE_25 is ...
# Sequence for node NODE_33 is ...
# Difference Score between NODE_25 and NODE_33 is 1
# Penalty Score between NODE_25 and NODE_33 is 2
# Total score is 3
# Sequence for node NODE_26 is ...
# Sequence for node XP_016124791.1 is ...
# Difference Score between NODE_26 and XP_016124791.1 is 0
# Penalty Score between NODE_26 and XP_016124791.1 is 0
# Total score is 0
# Sequence for node NODE_26 is ...
# Sequence for node NODE_34 is ...
# Difference Score between NODE_26 and NODE_34 is 0
# Penalty Score between NODE_26 and NODE_34 is 0
# Total score is 0
# Sequence for node NODE_27 is ...
# Sequence for node NODE_35 is ...
# Difference Score between NODE_27 and NODE_35 is 0
# Penalty Score between NODE_27 and NODE_35 is 0
# Total score is 0
# Sequence for node NODE_27 is ...
# Sequence for node NODE_36 is ...
# Difference Score between NODE_27 and NODE_36 is 0
# Penalty Score between NODE_27 and NODE_36 is 0
# Total score is 0
# Sequence for node NODE_28 is ...
# Sequence for node XP_020786184.1 is ...
# Difference Score between NODE_28 and XP_020786184.1 is 8
# Penalty Score between NODE_28 and XP_020786184.1 is 10
# Total score is 18
# Sequence for node NODE_28 is ...
# Sequence for node NODE_37 is ...
# Difference Score between NODE_28 and NODE_37 is 1
# Penalty Score between NODE_28 and NODE_37 is 2
# Total score is 3
# Sequence for node NODE_29 is ...
# Sequence for node XP_020652021.1 is ...
# Difference Score between NODE_29 and XP_020652021.1 is 66
# Penalty Score between NODE_29 and XP_020652021.1 is 18
# Total score is 84
# Sequence for node NODE_29 is ...
# Sequence for node NODE_38 is ...
# Difference Score between NODE_29 and NODE_38 is 27
# Penalty Score between NODE_29 and NODE_38 is 10
# Total score is 37
# Sequence for node NODE_30 is ...
# Sequence for node XP_006272957.2 is ...
# Difference Score between NODE_30 and XP_006272957.2 is 1
# Penalty Score between NODE_30 and XP_006272957.2 is 2
# Total score is 3
# Sequence for node NODE_30 is ...
# Sequence for node XP_019377492.1 is ...
# Difference Score between NODE_30 and XP_019377492.1 is 5
# Penalty Score between NODE_30 and XP_019377492.1 is 6
# Total score is 11
# Sequence for node NODE_31 is ...
# Sequence for node NODE_39 is ...
# Difference Score between NODE_31 and NODE_39 is 10
# Penalty Score between NODE_31 and NODE_39 is 4
# Total score is 14
# Sequence for node NODE_31 is ...
# Sequence for node NODE_40 is ...
# Difference Score between NODE_31 and NODE_40 is 24
# Penalty Score between NODE_31 and NODE_40 is 12
# Total score is 36
# Sequence for node NODE_32 is ...
# Sequence for node NODE_41 is ...
# Difference Score between NODE_32 and NODE_41 is 0
# Penalty Score between NODE_32 and NODE_41 is 0
# Total score is 0
# Sequence for node NODE_32 is ...
# Sequence for node XP_006869388.1 is ...
# Difference Score between NODE_32 and XP_006869388.1 is 0
# Penalty Score between NODE_32 and XP_006869388.1 is 0
# Total score is 0
# Sequence for node NODE_33 is ...
# Sequence for node XP_017556900.1 is ...
# Difference Score between NODE_33 and XP_017556900.1 is 0
# Penalty Score between NODE_33 and XP_017556900.1 is 0
# Total score is 0
# Sequence for node NODE_33 is ...
# Sequence for node XP_007229530.1 is ...
# Difference Score between NODE_33 and XP_007229530.1 is 0
# Penalty Score between NODE_33 and XP_007229530.1 is 0
# Total score is 0
# Sequence for node NODE_34 is ...
# Sequence for node XP_018919739.1 is ...
# Difference Score between NODE_34 and XP_018919739.1 is 0
# Penalty Score between NODE_34 and XP_018919739.1 is 0
# Total score is 0
# Sequence for node NODE_34 is ...
# Sequence for node NODE_42 is ...
# Difference Score between NODE_34 and NODE_42 is 0
# Penalty Score between NODE_34 and NODE_42 is 0
# Total score is 0
# Sequence for node NODE_35 is ...
# Sequence for node XP_021429049.1 is ...
# Difference Score between NODE_35 and XP_021429049.1 is 0
# Penalty Score between NODE_35 and XP_021429049.1 is 0
# Total score is 0
# Sequence for node NODE_35 is ...
# Sequence for node XP_021429054.1 is ...
# Difference Score between NODE_35 and XP_021429054.1 is 0
# Penalty Score between NODE_35 and XP_021429054.1 is 0
# Total score is 0
# Sequence for node NODE_36 is ...
# Sequence for node XP_014050304.1 is ...
# Difference Score between NODE_36 and XP_014050304.1 is 0
# Penalty Score between NODE_36 and XP_014050304.1 is 0
# Total score is 0
# Sequence for node NODE_36 is ...
# Sequence for node XP_014065111.1 is ...
# Difference Score between NODE_36 and XP_014065111.1 is 3
# Penalty Score between NODE_36 and XP_014065111.1 is 2
# Total score is 5
# Sequence for node NODE_37 is ...
# Sequence for node NODE_43 is ...
# Difference Score between NODE_37 and NODE_43 is 0
# Penalty Score between NODE_37 and NODE_43 is 0
# Total score is 0
# Sequence for node NODE_37 is ...
# Sequence for node NODE_44 is ...
# Difference Score between NODE_37 and NODE_44 is 1
# Penalty Score between NODE_37 and NODE_44 is 2
# Total score is 3
# Sequence for node NODE_38 is ...
# Sequence for node XP_007421378.1 is ...
# Difference Score between NODE_38 and XP_007421378.1 is 2
# Penalty Score between NODE_38 and XP_007421378.1 is 4
# Total score is 6
# Sequence for node NODE_38 is ...
# Sequence for node XP_015665994.1 is ...
# Difference Score between NODE_38 and XP_015665994.1 is 4
# Penalty Score between NODE_38 and XP_015665994.1 is 4
# Total score is 8
# Sequence for node NODE_39 is ...
# Sequence for node XP_021251581.1 is ...
# Difference Score between NODE_39 and XP_021251581.1 is 0
# Penalty Score between NODE_39 and XP_021251581.1 is 0
# Total score is 0
# Sequence for node NODE_39 is ...
# Sequence for node NODE_45 is ...
# Difference Score between NODE_39 and NODE_45 is 0
# Penalty Score between NODE_39 and NODE_45 is 0
# Total score is 0
# Sequence for node NODE_40 is ...
# Sequence for node NODE_46 is ...
# Difference Score between NODE_40 and NODE_46 is 0
# Penalty Score between NODE_40 and NODE_46 is 0
# Total score is 0
# Sequence for node NODE_40 is ...
# Sequence for node NODE_47 is ...
# Difference Score between NODE_40 and NODE_47 is 34
# Penalty Score between NODE_40 and NODE_47 is 6
# Total score is 40
# Sequence for node NODE_41 is ...
# Sequence for node NODE_48 is ...
# Difference Score between NODE_41 and NODE_48 is 0
# Penalty Score between NODE_41 and NODE_48 is 0
# Total score is 0
# Sequence for node NODE_41 is ...
# Sequence for node XP_007938960.1 is ...
# Difference Score between NODE_41 and XP_007938960.1 is 0
# Penalty Score between NODE_41 and XP_007938960.1 is 0
# Total score is 0
# Sequence for node NODE_42 is ...
# Sequence for node NODE_49 is ...
# Difference Score between NODE_42 and NODE_49 is 0
# Penalty Score between NODE_42 and NODE_49 is 0
# Total score is 0
# Sequence for node NODE_42 is ...
# Sequence for node NP_001139036.1 is ...
# Difference Score between NODE_42 and NP_001139036.1 is 0
# Penalty Score between NODE_42 and NP_001139036.1 is 0
# Total score is 0
# Sequence for node NODE_43 is ...
# Sequence for node XP_020447513.1 is ...
# Difference Score between NODE_43 and XP_020447513.1 is 5
# Penalty Score between NODE_43 and XP_020447513.1 is 4
# Total score is 9
# Sequence for node NODE_43 is ...
# Sequence for node NODE_50 is ...
# Difference Score between NODE_43 and NODE_50 is 0
# Penalty Score between NODE_43 and NODE_50 is 0
# Total score is 0
# Sequence for node NODE_44 is ...
# Sequence for node XP_010778816.1 is ...
# Difference Score between NODE_44 and XP_010778816.1 is 2
# Penalty Score between NODE_44 and XP_010778816.1 is 4
# Total score is 6
# Sequence for node NODE_44 is ...
# Sequence for node NODE_51 is ...
# Difference Score between NODE_44 and NODE_51 is 0
# Penalty Score between NODE_44 and NODE_51 is 0
# Total score is 0
# Sequence for node NODE_45 is ...
# Sequence for node XP_420491.4 is ...
# Difference Score between NODE_45 and XP_420491.4 is 3
# Penalty Score between NODE_45 and XP_420491.4 is 4
# Total score is 7
# Sequence for node NODE_45 is ...
# Sequence for node NODE_52 is ...
# Difference Score between NODE_45 and NODE_52 is 0
# Penalty Score between NODE_45 and NODE_52 is 0
# Total score is 0
# Sequence for node NODE_46 is ...
# Sequence for node XP_011572877.1 is ...
# Difference Score between NODE_46 and XP_011572877.1 is 39
# Penalty Score between NODE_46 and XP_011572877.1 is 14
# Total score is 53
# Sequence for node NODE_46 is ...
# Sequence for node XP_010584537.1 is ...
# Difference Score between NODE_46 and XP_010584537.1 is 8
# Penalty Score between NODE_46 and XP_010584537.1 is 4
# Total score is 12
# Sequence for node NODE_47 is ...
# Sequence for node NODE_53 is ...
# Difference Score between NODE_47 and NODE_53 is 0
# Penalty Score between NODE_47 and NODE_53 is 0
# Total score is 0
# Sequence for node NODE_47 is ...
# Sequence for node NODE_54 is ...
# Difference Score between NODE_47 and NODE_54 is 11
# Penalty Score between NODE_47 and NODE_54 is 6
# Total score is 17
# Sequence for node NODE_48 is ...
# Sequence for node NODE_55 is ...
# Difference Score between NODE_48 and NODE_55 is 0
# Penalty Score between NODE_48 and NODE_55 is 0
# Total score is 0
# Sequence for node NODE_48 is ...
# Sequence for node NODE_56 is ...
# Difference Score between NODE_48 and NODE_56 is 0
# Penalty Score between NODE_48 and NODE_56 is 0
# Total score is 0
# Sequence for node NODE_49 is ...
# Sequence for node XP_016395320.1 is ...
# Difference Score between NODE_49 and XP_016395320.1 is 0
# Penalty Score between NODE_49 and XP_016395320.1 is 0
# Total score is 0
# Sequence for node NODE_49 is ...
# Sequence for node NODE_57 is ...
# Difference Score between NODE_49 and NODE_57 is 4
# Penalty Score between NODE_49 and NODE_57 is 2
# Total score is 6
# Sequence for node NODE_50 is ...
# Sequence for node NODE_58 is ...
# Difference Score between NODE_50 and NODE_58 is 1
# Penalty Score between NODE_50 and NODE_58 is 2
# Total score is 3
# Sequence for node NODE_50 is ...
# Sequence for node NODE_59 is ...
# Difference Score between NODE_50 and NODE_59 is 2
# Penalty Score between NODE_50 and NODE_59 is 2
# Total score is 4
# Sequence for node NODE_51 is ...
# Sequence for node NODE_60 is ...
# Difference Score between NODE_51 and NODE_60 is 1
# Penalty Score between NODE_51 and NODE_60 is 2
# Total score is 3
# Sequence for node NODE_51 is ...
# Sequence for node NODE_61 is ...
# Difference Score between NODE_51 and NODE_61 is 6
# Penalty Score between NODE_51 and NODE_61 is 4
# Total score is 10
# Sequence for node NODE_52 is ...
# Sequence for node XP_010708185.2 is ...
# Difference Score between NODE_52 and XP_010708185.2 is 90
# Penalty Score between NODE_52 and XP_010708185.2 is 28
# Total score is 118
# Sequence for node NODE_52 is ...
# Sequence for node XP_015716841.1 is ...
# Difference Score between NODE_52 and XP_015716841.1 is 0
# Penalty Score between NODE_52 and XP_015716841.1 is 0
# Total score is 0
# Sequence for node NODE_53 is ...
# Sequence for node NODE_62 is ...
# Difference Score between NODE_53 and NODE_62 is 59
# Penalty Score between NODE_53 and NODE_62 is 14
# Total score is 73
# Sequence for node NODE_53 is ...
# Sequence for node NODE_63 is ...
# Difference Score between NODE_53 and NODE_63 is 3
# Penalty Score between NODE_53 and NODE_63 is 4
# Total score is 7
# Sequence for node NODE_54 is ...
# Sequence for node XP_005148751.1 is ...
# Difference Score between NODE_54 and XP_005148751.1 is 20
# Penalty Score between NODE_54 and XP_005148751.1 is 2
# Total score is 22
# Sequence for node NODE_54 is ...
# Sequence for node NODE_64 is ...
# Difference Score between NODE_54 and NODE_64 is 0
# Penalty Score between NODE_54 and NODE_64 is 0
# Total score is 0
# Sequence for node NODE_55 is ...
# Sequence for node XP_003410436.1 is ...
# Difference Score between NODE_55 and XP_003410436.1 is 0
# Penalty Score between NODE_55 and XP_003410436.1 is 0
# Total score is 0
# Sequence for node NODE_55 is ...
# Sequence for node XP_004380279.1 is ...
# Difference Score between NODE_55 and XP_004380279.1 is 0
# Penalty Score between NODE_55 and XP_004380279.1 is 0
# Total score is 0
# Sequence for node NODE_56 is ...
# Sequence for node NODE_65 is ...
# Difference Score between NODE_56 and NODE_65 is 0
# Penalty Score between NODE_56 and NODE_65 is 0
# Total score is 0
# Sequence for node NODE_56 is ...
# Sequence for node NODE_66 is ...
# Difference Score between NODE_56 and NODE_66 is 0
# Penalty Score between NODE_56 and NODE_66 is 0
# Total score is 0
# Sequence for node NODE_57 is ...
# Sequence for node XP_018919738.1 is ...
# Difference Score between NODE_57 and XP_018919738.1 is 0
# Penalty Score between NODE_57 and XP_018919738.1 is 0
# Total score is 0
# Sequence for node NODE_57 is ...
# Sequence for node KTF87224.1 is ...
# Difference Score between NODE_57 and KTF87224.1 is 0
# Penalty Score between NODE_57 and KTF87224.1 is 0
# Total score is 0
# Sequence for node NODE_58 is ...
# Sequence for node XP_008315700.1 is ...
# Difference Score between NODE_58 and XP_008315700.1 is 7
# Penalty Score between NODE_58 and XP_008315700.1 is 8
# Total score is 15
# Sequence for node NODE_58 is ...
# Sequence for node XP_019956775.1 is ...
# Difference Score between NODE_58 and XP_019956775.1 is 4
# Penalty Score between NODE_58 and XP_019956775.1 is 4
# Total score is 8
# Sequence for node NODE_59 is ...
# Sequence for node NODE_67 is ...
# Difference Score between NODE_59 and NODE_67 is 1
# Penalty Score between NODE_59 and NODE_67 is 2
# Total score is 3
# Sequence for node NODE_59 is ...
# Sequence for node XP_018539665.1 is ...
# Difference Score between NODE_59 and XP_018539665.1 is 0
# Penalty Score between NODE_59 and XP_018539665.1 is 0
# Total score is 0
# Sequence for node NODE_60 is ...
# Sequence for node NODE_68 is ...
# Difference Score between NODE_60 and NODE_68 is 7
# Penalty Score between NODE_60 and NODE_68 is 4
# Total score is 11
# Sequence for node NODE_60 is ...
# Sequence for node NODE_69 is ...
# Difference Score between NODE_60 and NODE_69 is 3
# Penalty Score between NODE_60 and NODE_69 is 6
# Total score is 9
# Sequence for node NODE_61 is ...
# Sequence for node NODE_70 is ...
# Difference Score between NODE_61 and NODE_70 is 4
# Penalty Score between NODE_61 and NODE_70 is 4
# Total score is 8
# Sequence for node NODE_61 is ...
# Sequence for node NODE_71 is ...
# Difference Score between NODE_61 and NODE_71 is 0
# Penalty Score between NODE_61 and NODE_71 is 0
# Total score is 0
# Sequence for node NODE_62 is ...
# Sequence for node NODE_72 is ...
# Difference Score between NODE_62 and NODE_72 is 0
# Penalty Score between NODE_62 and NODE_72 is 0
# Total score is 0
# Sequence for node NODE_62 is ...
# Sequence for node NODE_73 is ...
# Difference Score between NODE_62 and NODE_73 is 1
# Penalty Score between NODE_62 and NODE_73 is 2
# Total score is 3
# Sequence for node NODE_63 is ...
# Sequence for node KFV68671.1 is ...
# Difference Score between NODE_63 and KFV68671.1 is 1
# Penalty Score between NODE_63 and KFV68671.1 is 2
# Total score is 3
# Sequence for node NODE_63 is ...
# Sequence for node XP_009900551.1 is ...
# Difference Score between NODE_63 and XP_009900551.1 is 1
# Penalty Score between NODE_63 and XP_009900551.1 is 2
# Total score is 3
# Sequence for node NODE_64 is ...
# Sequence for node OPJ75701.1 is ...
# Difference Score between NODE_64 and OPJ75701.1 is 11
# Penalty Score between NODE_64 and OPJ75701.1 is 2
# Total score is 13
# Sequence for node NODE_64 is ...
# Sequence for node NODE_74 is ...
# Difference Score between NODE_64 and NODE_74 is 5
# Penalty Score between NODE_64 and NODE_74 is 6
# Total score is 11
# Sequence for node NODE_65 is ...
# Sequence for node NODE_75 is ...
# Difference Score between NODE_65 and NODE_75 is 0
# Penalty Score between NODE_65 and NODE_75 is 0
# Total score is 0
# Sequence for node NODE_65 is ...
# Sequence for node NODE_76 is ...
# Difference Score between NODE_65 and NODE_76 is 0
# Penalty Score between NODE_65 and NODE_76 is 0
# Total score is 0
# Sequence for node NODE_66 is ...
# Sequence for node NODE_77 is ...
# Difference Score between NODE_66 and NODE_77 is 0
# Penalty Score between NODE_66 and NODE_77 is 0
# Total score is 0
# Sequence for node NODE_66 is ...
# Sequence for node XP_012374116.2 is ...
# Difference Score between NODE_66 and XP_012374116.2 is 93
# Penalty Score between NODE_66 and XP_012374116.2 is 30
# Total score is 123
# Sequence for node NODE_67 is ...
# Sequence for node XP_023283957.1 is ...
# Difference Score between NODE_67 and XP_023283957.1 is 0
# Penalty Score between NODE_67 and XP_023283957.1 is 0
# Total score is 0
# Sequence for node NODE_67 is ...
# Sequence for node XP_022621190.1 is ...
# Difference Score between NODE_67 and XP_022621190.1 is 0
# Penalty Score between NODE_67 and XP_022621190.1 is 0
# Total score is 0
# Sequence for node NODE_68 is ...
# Sequence for node CAG11477.1 is ...
# Difference Score between NODE_68 and CAG11477.1 is 0
# Penalty Score between NODE_68 and CAG11477.1 is 0
# Total score is 0
# Sequence for node NODE_68 is ...
# Sequence for node XP_011611201.1 is ...
# Difference Score between NODE_68 and XP_011611201.1 is 0
# Penalty Score between NODE_68 and XP_011611201.1 is 0
# Total score is 0
# Sequence for node NODE_69 is ...
# Sequence for node XP_010739611.2 is ...
# Difference Score between NODE_69 and XP_010739611.2 is 0
# Penalty Score between NODE_69 and XP_010739611.2 is 0
# Total score is 0
# Sequence for node NODE_69 is ...
# Sequence for node XP_019110856.1 is ...
# Difference Score between NODE_69 and XP_019110856.1 is 0
# Penalty Score between NODE_69 and XP_019110856.1 is 0
# Total score is 0
# Sequence for node NODE_70 is ...
# Sequence for node NODE_78 is ...
# Difference Score between NODE_70 and NODE_78 is 3
# Penalty Score between NODE_70 and NODE_78 is 4
# Total score is 7
# Sequence for node NODE_70 is ...
# Sequence for node NODE_79 is ...
# Difference Score between NODE_70 and NODE_79 is 0
# Penalty Score between NODE_70 and NODE_79 is 0
# Total score is 0
# Sequence for node NODE_71 is ...
# Sequence for node NODE_80 is ...
# Difference Score between NODE_71 and NODE_80 is 1
# Penalty Score between NODE_71 and NODE_80 is 2
# Total score is 3
# Sequence for node NODE_71 is ...
# Sequence for node NODE_81 is ...
# Difference Score between NODE_71 and NODE_81 is 4
# Penalty Score between NODE_71 and NODE_81 is 4
# Total score is 8
# Sequence for node NODE_72 is ...
# Sequence for node KFW75712.1 is ...
# Difference Score between NODE_72 and KFW75712.1 is 77
# Penalty Score between NODE_72 and KFW75712.1 is 22
# Total score is 99
# Sequence for node NODE_72 is ...
# Sequence for node XP_017688993.1 is ...
# Difference Score between NODE_72 and XP_017688993.1 is 15
# Penalty Score between NODE_72 and XP_017688993.1 is 4
# Total score is 19
# Sequence for node NODE_73 is ...
# Sequence for node NODE_82 is ...
# Difference Score between NODE_73 and NODE_82 is 0
# Penalty Score between NODE_73 and NODE_82 is 0
# Total score is 0
# Sequence for node NODE_73 is ...
# Sequence for node NODE_83 is ...
# Difference Score between NODE_73 and NODE_83 is 15
# Penalty Score between NODE_73 and NODE_83 is 4
# Total score is 19
# Sequence for node NODE_74 is ...
# Sequence for node XP_010077161.1 is ...
# Difference Score between NODE_74 and XP_010077161.1 is 1
# Penalty Score between NODE_74 and XP_010077161.1 is 2
# Total score is 3
# Sequence for node NODE_74 is ...
# Sequence for node NODE_84 is ...
# Difference Score between NODE_74 and NODE_84 is 9
# Penalty Score between NODE_74 and NODE_84 is 2
# Total score is 11
# Sequence for node NODE_75 is ...
# Sequence for node XP_016016320.1 is ...
# Difference Score between NODE_75 and XP_016016320.1 is 2
# Penalty Score between NODE_75 and XP_016016320.1 is 2
# Total score is 4
# Sequence for node NODE_75 is ...
# Sequence for node NODE_85 is ...
# Difference Score between NODE_75 and NODE_85 is 0
# Penalty Score between NODE_75 and NODE_85 is 0
# Total score is 0
# Sequence for node NODE_76 is ...
# Sequence for node NODE_86 is ...
# Difference Score between NODE_76 and NODE_86 is 0
# Penalty Score between NODE_76 and NODE_86 is 0
# Total score is 0
# Sequence for node NODE_76 is ...
# Sequence for node NODE_87 is ...
# Difference Score between NODE_76 and NODE_87 is 0
# Penalty Score between NODE_76 and NODE_87 is 0
# Total score is 0
# Sequence for node NODE_77 is ...
# Sequence for node NODE_88 is ...
# Difference Score between NODE_77 and NODE_88 is 1
# Penalty Score between NODE_77 and NODE_88 is 2
# Total score is 3
# Sequence for node NODE_77 is ...
# Sequence for node NODE_89 is ...
# Difference Score between NODE_77 and NODE_89 is 0
# Penalty Score between NODE_77 and NODE_89 is 0
# Total score is 0
# Sequence for node NODE_78 is ...
# Sequence for node XP_005797710.1 is ...
# Difference Score between NODE_78 and XP_005797710.1 is 2
# Penalty Score between NODE_78 and XP_005797710.1 is 2
# Total score is 4
# Sequence for node NODE_78 is ...
# Sequence for node NODE_90 is ...
# Difference Score between NODE_78 and NODE_90 is 0
# Penalty Score between NODE_78 and NODE_90 is 0
# Total score is 0
# Sequence for node NODE_79 is ...
# Sequence for node NODE_91 is ...
# Difference Score between NODE_79 and NODE_91 is 0
# Penalty Score between NODE_79 and NODE_91 is 0
# Total score is 0
# Sequence for node NODE_79 is ...
# Sequence for node XP_015799181.1 is ...
# Difference Score between NODE_79 and XP_015799181.1 is 8
# Penalty Score between NODE_79 and XP_015799181.1 is 12
# Total score is 20
# Sequence for node NODE_80 is ...
# Sequence for node XP_020559182.2 is ...
# Difference Score between NODE_80 and XP_020559182.2 is 0
# Penalty Score between NODE_80 and XP_020559182.2 is 0
# Total score is 0
# Sequence for node NODE_80 is ...
# Sequence for node AGN04284.1 is ...
# Difference Score between NODE_80 and AGN04284.1 is 7
# Penalty Score between NODE_80 and AGN04284.1 is 6
# Total score is 13
# Sequence for node NODE_81 is ...
# Sequence for node NODE_92 is ...
# Difference Score between NODE_81 and NODE_92 is 0
# Penalty Score between NODE_81 and NODE_92 is 0
# Total score is 0
# Sequence for node NODE_81 is ...
# Sequence for node NODE_93 is ...
# Difference Score between NODE_81 and NODE_93 is 9
# Penalty Score between NODE_81 and NODE_93 is 10
# Total score is 19
# Sequence for node NODE_82 is ...
# Sequence for node XP_014733783.1 is ...
# Difference Score between NODE_82 and XP_014733783.1 is 15
# Penalty Score between NODE_82 and XP_014733783.1 is 4
# Total score is 19
# Sequence for node NODE_82 is ...
# Sequence for node XP_005044990.1 is ...
# Difference Score between NODE_82 and XP_005044990.1 is 25
# Penalty Score between NODE_82 and XP_005044990.1 is 10
# Total score is 35
# Sequence for node NODE_83 is ...
# Sequence for node NODE_94 is ...
# Difference Score between NODE_83 and NODE_94 is 0
# Penalty Score between NODE_83 and NODE_94 is 0
# Total score is 0
# Sequence for node NODE_83 is ...
# Sequence for node NODE_95 is ...
# Difference Score between NODE_83 and NODE_95 is 0
# Penalty Score between NODE_83 and NODE_95 is 0
# Total score is 0
# Sequence for node NODE_84 is ...
# Sequence for node KFO79198.1 is ...
# Difference Score between NODE_84 and KFO79198.1 is 0
# Penalty Score between NODE_84 and KFO79198.1 is 0
# Total score is 0
# Sequence for node NODE_84 is ...
# Sequence for node XP_014796211.1 is ...
# Difference Score between NODE_84 and XP_014796211.1 is 71
# Penalty Score between NODE_84 and XP_014796211.1 is 20
# Total score is 91
# Sequence for node NODE_85 is ...
# Sequence for node NODE_96 is ...
# Difference Score between NODE_85 and NODE_96 is 1
# Penalty Score between NODE_85 and NODE_96 is 2
# Total score is 3
# Sequence for node NODE_85 is ...
# Sequence for node NODE_97 is ...
# Difference Score between NODE_85 and NODE_97 is 1
# Penalty Score between NODE_85 and NODE_97 is 2
# Total score is 3
# Sequence for node NODE_86 is ...
# Sequence for node XP_014694538.1 is ...
# Difference Score between NODE_86 and XP_014694538.1 is 116
# Penalty Score between NODE_86 and XP_014694538.1 is 34
# Total score is 150
# Sequence for node NODE_86 is ...
# Sequence for node NODE_98 is ...
# Difference Score between NODE_86 and NODE_98 is 0
# Penalty Score between NODE_86 and NODE_98 is 0
# Total score is 0
# Sequence for node NODE_87 is ...
# Sequence for node NODE_99 is ...
# Difference Score between NODE_87 and NODE_99 is 19
# Penalty Score between NODE_87 and NODE_99 is 10
# Total score is 29
# Sequence for node NODE_87 is ...
# Sequence for node NODE_100 is ...
# Difference Score between NODE_87 and NODE_100 is 1
# Penalty Score between NODE_87 and NODE_100 is 2
# Total score is 3
# Sequence for node NODE_88 is ...
# Sequence for node XP_004594327.1 is ...
# Difference Score between NODE_88 and XP_004594327.1 is 2
# Penalty Score between NODE_88 and XP_004594327.1 is 2
# Total score is 4
# Sequence for node NODE_88 is ...
# Sequence for node XP_002717221.1 is ...
# Difference Score between NODE_88 and XP_002717221.1 is 3
# Penalty Score between NODE_88 and XP_002717221.1 is 2
# Total score is 5
# Sequence for node NODE_89 is ...
# Sequence for node NODE_101 is ...
# Difference Score between NODE_89 and NODE_101 is 0
# Penalty Score between NODE_89 and NODE_101 is 0
# Total score is 0
# Sequence for node NODE_89 is ...
# Sequence for node NODE_102 is ...
# Difference Score between NODE_89 and NODE_102 is 0
# Penalty Score between NODE_89 and NODE_102 is 0
# Total score is 0
# Sequence for node NODE_90 is ...
# Sequence for node XP_008420764.1 is ...
# Difference Score between NODE_90 and XP_008420764.1 is 2
# Penalty Score between NODE_90 and XP_008420764.1 is 4
# Total score is 6
# Sequence for node NODE_90 is ...
# Sequence for node NODE_103 is ...
# Difference Score between NODE_90 and NODE_103 is 0
# Penalty Score between NODE_90 and NODE_103 is 0
# Total score is 0
# Sequence for node NODE_91 is ...
# Sequence for node XP_013863208.1 is ...
# Difference Score between NODE_91 and XP_013863208.1 is 12
# Penalty Score between NODE_91 and XP_013863208.1 is 6
# Total score is 18
# Sequence for node NODE_91 is ...
# Sequence for node XP_017268014.1 is ...
# Difference Score between NODE_91 and XP_017268014.1 is 3
# Penalty Score between NODE_91 and XP_017268014.1 is 2
# Total score is 5
# Sequence for node NODE_92 is ...
# Sequence for node XP_008285532.1 is ...
# Difference Score between NODE_92 and XP_008285532.1 is 7
# Penalty Score between NODE_92 and XP_008285532.1 is 6
# Total score is 13
# Sequence for node NODE_92 is ...
# Sequence for node NODE_104 is ...
# Difference Score between NODE_92 and NODE_104 is 2
# Penalty Score between NODE_92 and NODE_104 is 2
# Total score is 4
# Sequence for node NODE_93 is ...
# Sequence for node NODE_105 is ...
# Difference Score between NODE_93 and NODE_105 is 0
# Penalty Score between NODE_93 and NODE_105 is 0
# Total score is 0
# Sequence for node NODE_93 is ...
# Sequence for node XP_005457042.1 is ...
# Difference Score between NODE_93 and XP_005457042.1 is 0
# Penalty Score between NODE_93 and XP_005457042.1 is 0
# Total score is 0
# Sequence for node NODE_94 is ...
# Sequence for node NODE_106 is ...
# Difference Score between NODE_94 and NODE_106 is 0
# Penalty Score between NODE_94 and NODE_106 is 0
# Total score is 0
# Sequence for node NODE_94 is ...
# Sequence for node NODE_107 is ...
# Difference Score between NODE_94 and NODE_107 is 0
# Penalty Score between NODE_94 and NODE_107 is 0
# Total score is 0
# Sequence for node NODE_95 is ...
# Sequence for node XP_015480586.1 is ...
# Difference Score between NODE_95 and XP_015480586.1 is 0
# Penalty Score between NODE_95 and XP_015480586.1 is 0
# Total score is 0
# Sequence for node NODE_95 is ...
# Sequence for node XP_005518034.1 is ...
# Difference Score between NODE_95 and XP_005518034.1 is 0
# Penalty Score between NODE_95 and XP_005518034.1 is 0
# Total score is 0
# Sequence for node NODE_96 is ...
# Sequence for node XP_019491595.1 is ...
# Difference Score between NODE_96 and XP_019491595.1 is 0
# Penalty Score between NODE_96 and XP_019491595.1 is 0
# Total score is 0
# Sequence for node NODE_96 is ...
# Sequence for node XP_019597472.1 is ...
# Difference Score between NODE_96 and XP_019597472.1 is 0
# Penalty Score between NODE_96 and XP_019597472.1 is 0
# Total score is 0
# Sequence for node NODE_97 is ...
# Sequence for node XP_016069983.1 is ...
# Difference Score between NODE_97 and XP_016069983.1 is 52
# Penalty Score between NODE_97 and XP_016069983.1 is 18
# Total score is 70
# Sequence for node NODE_97 is ...
# Sequence for node NODE_108 is ...
# Difference Score between NODE_97 and NODE_108 is 0
# Penalty Score between NODE_97 and NODE_108 is 0
# Total score is 0
# Sequence for node NODE_98 is ...
# Sequence for node NODE_109 is ...
# Difference Score between NODE_98 and NODE_109 is 0
# Penalty Score between NODE_98 and NODE_109 is 0
# Total score is 0
# Sequence for node NODE_98 is ...
# Sequence for node NODE_110 is ...
# Difference Score between NODE_98 and NODE_110 is 0
# Penalty Score between NODE_98 and NODE_110 is 0
# Total score is 0
# Sequence for node NODE_99 is ...
# Sequence for node XP_006212134.1 is ...
# Difference Score between NODE_99 and XP_006212134.1 is 47
# Penalty Score between NODE_99 and XP_006212134.1 is 12
# Total score is 59
# Sequence for node NODE_99 is ...
# Sequence for node NODE_111 is ...
# Difference Score between NODE_99 and NODE_111 is 0
# Penalty Score between NODE_99 and NODE_111 is 0
# Total score is 0
# Sequence for node NODE_100 is ...
# Sequence for node XP_003129312.1 is ...
# Difference Score between NODE_100 and XP_003129312.1 is 0
# Penalty Score between NODE_100 and XP_003129312.1 is 0
# Total score is 0
# Sequence for node NODE_100 is ...
# Sequence for node NODE_112 is ...
# Difference Score between NODE_100 and NODE_112 is 0
# Penalty Score between NODE_100 and NODE_112 is 0
# Total score is 0
# Sequence for node NODE_101 is ...
# Sequence for node NODE_113 is ...
# Difference Score between NODE_101 and NODE_113 is 0
# Penalty Score between NODE_101 and NODE_113 is 0
# Total score is 0
# Sequence for node NODE_101 is ...
# Sequence for node NODE_114 is ...
# Difference Score between NODE_101 and NODE_114 is 0
# Penalty Score between NODE_101 and NODE_114 is 0
# Total score is 0
# Sequence for node NODE_102 is ...
# Sequence for node NODE_115 is ...
# Difference Score between NODE_102 and NODE_115 is 0
# Penalty Score between NODE_102 and NODE_115 is 0
# Total score is 0
# Sequence for node NODE_102 is ...
# Sequence for node NODE_116 is ...
# Difference Score between NODE_102 and NODE_116 is 3
# Penalty Score between NODE_102 and NODE_116 is 2
# Total score is 5
# Sequence for node NODE_103 is ...
# Sequence for node XP_014905426.1 is ...
# Difference Score between NODE_103 and XP_014905426.1 is 0
# Penalty Score between NODE_103 and XP_014905426.1 is 0
# Total score is 0
# Sequence for node NODE_103 is ...
# Sequence for node XP_007560680.1 is ...
# Difference Score between NODE_103 and XP_007560680.1 is 0
# Penalty Score between NODE_103 and XP_007560680.1 is 0
# Total score is 0
# Sequence for node NODE_104 is ...
# Sequence for node XP_023129780.1 is ...
# Difference Score between NODE_104 and XP_023129780.1 is 2
# Penalty Score between NODE_104 and XP_023129780.1 is 2
# Total score is 4
# Sequence for node NODE_104 is ...
# Sequence for node XP_022077378.1 is ...
# Difference Score between NODE_104 and XP_022077378.1 is 0
# Penalty Score between NODE_104 and XP_022077378.1 is 0
# Total score is 0
# Sequence for node NODE_105 is ...
# Sequence for node XP_006787161.1 is ...
# Difference Score between NODE_105 and XP_006787161.1 is 12
# Penalty Score between NODE_105 and XP_006787161.1 is 2
# Total score is 14
# Sequence for node NODE_105 is ...
# Sequence for node XP_004549474.1 is ...
# Difference Score between NODE_105 and XP_004549474.1 is 0
# Penalty Score between NODE_105 and XP_004549474.1 is 0
# Total score is 0
# Sequence for node NODE_106 is ...
# Sequence for node XP_010410415.1 is ...
# Difference Score between NODE_106 and XP_010410415.1 is 104
# Penalty Score between NODE_106 and XP_010410415.1 is 28
# Total score is 132
# Sequence for node NODE_106 is ...
# Sequence for node XP_009099794.1 is ...
# Difference Score between NODE_106 and XP_009099794.1 is 0
# Penalty Score between NODE_106 and XP_009099794.1 is 0
# Total score is 0
# Sequence for node NODE_107 is ...
# Sequence for node XP_005484794.1 is ...
# Difference Score between NODE_107 and XP_005484794.1 is 0
# Penalty Score between NODE_107 and XP_005484794.1 is 0
# Total score is 0
# Sequence for node NODE_107 is ...
# Sequence for node NODE_117 is ...
# Difference Score between NODE_107 and NODE_117 is 0
# Penalty Score between NODE_107 and NODE_117 is 0
# Total score is 0
# Sequence for node NODE_108 is ...
# Sequence for node XP_008148480.1 is ...
# Difference Score between NODE_108 and XP_008148480.1 is 0
# Penalty Score between NODE_108 and XP_008148480.1 is 0
# Total score is 0
# Sequence for node NODE_108 is ...
# Sequence for node NODE_118 is ...
# Difference Score between NODE_108 and NODE_118 is 0
# Penalty Score between NODE_108 and NODE_118 is 0
# Total score is 0
# Sequence for node NODE_109 is ...
# Sequence for node EFB16740.1 is ...
# Difference Score between NODE_109 and EFB16740.1 is 61
# Penalty Score between NODE_109 and EFB16740.1 is 22
# Total score is 83
# Sequence for node NODE_109 is ...
# Sequence for node NODE_119 is ...
# Difference Score between NODE_109 and NODE_119 is 0
# Penalty Score between NODE_109 and NODE_119 is 0
# Total score is 0
# Sequence for node NODE_110 is ...
# Sequence for node XP_019272345.1 is ...
# Difference Score between NODE_110 and XP_019272345.1 is 1
# Penalty Score between NODE_110 and XP_019272345.1 is 2
# Total score is 3
# Sequence for node NODE_110 is ...
# Sequence for node XP_019684690.2 is ...
# Difference Score between NODE_110 and XP_019684690.2 is 0
# Penalty Score between NODE_110 and XP_019684690.2 is 0
# Total score is 0
# Sequence for node NODE_111 is ...
# Sequence for node XP_010997363.1 is ...
# Difference Score between NODE_111 and XP_010997363.1 is 19
# Penalty Score between NODE_111 and XP_010997363.1 is 10
# Total score is 29
# Sequence for node NODE_111 is ...
# Sequence for node XP_010951941.1 is ...
# Difference Score between NODE_111 and XP_010951941.1 is 11
# Penalty Score between NODE_111 and XP_010951941.1 is 4
# Total score is 15
# Sequence for node NODE_112 is ...
# Sequence for node NODE_120 is ...
# Difference Score between NODE_112 and NODE_120 is 0
# Penalty Score between NODE_112 and NODE_120 is 0
# Total score is 0
# Sequence for node NODE_112 is ...
# Sequence for node NODE_121 is ...
# Difference Score between NODE_112 and NODE_121 is 0
# Penalty Score between NODE_112 and NODE_121 is 0
# Total score is 0
# Sequence for node NODE_113 is ...
# Sequence for node XP_006162319.2 is ...
# Difference Score between NODE_113 and XP_006162319.2 is 13
# Penalty Score between NODE_113 and XP_006162319.2 is 10
# Total score is 23
# Sequence for node NODE_113 is ...
# Sequence for node NODE_122 is ...
# Difference Score between NODE_113 and NODE_122 is 20
# Penalty Score between NODE_113 and NODE_122 is 8
# Total score is 28
# Sequence for node NODE_114 is ...
# Sequence for node XP_013220884.1 is ...
# Difference Score between NODE_114 and XP_013220884.1 is 2
# Penalty Score between NODE_114 and XP_013220884.1 is 4
# Total score is 6
# Sequence for node NODE_114 is ...
# Sequence for node NODE_123 is ...
# Difference Score between NODE_114 and NODE_123 is 0
# Penalty Score between NODE_114 and NODE_123 is 0
# Total score is 0
# Sequence for node NODE_115 is ...
# Sequence for node XP_008054185.1 is ...
# Difference Score between NODE_115 and XP_008054185.1 is 0
# Penalty Score between NODE_115 and XP_008054185.1 is 0
# Total score is 0
# Sequence for node NODE_115 is ...
# Sequence for node NODE_124 is ...
# Difference Score between NODE_115 and NODE_124 is 0
# Penalty Score between NODE_115 and NODE_124 is 0
# Total score is 0
# Sequence for node NODE_116 is ...
# Sequence for node XP_003796393.1 is ...
# Difference Score between NODE_116 and XP_003796393.1 is 0
# Penalty Score between NODE_116 and XP_003796393.1 is 0
# Total score is 0
# Sequence for node NODE_116 is ...
# Sequence for node XP_012621711.1 is ...
# Difference Score between NODE_116 and XP_012621711.1 is 15
# Penalty Score between NODE_116 and XP_012621711.1 is 6
# Total score is 21
# Sequence for node NODE_117 is ...
# Sequence for node XP_021381195.1 is ...
# Difference Score between NODE_117 and XP_021381195.1 is 0
# Penalty Score between NODE_117 and XP_021381195.1 is 0
# Total score is 0
# Sequence for node NODE_117 is ...
# Sequence for node XP_002194737.2 is ...
# Difference Score between NODE_117 and XP_002194737.2 is 0
# Penalty Score between NODE_117 and XP_002194737.2 is 0
# Total score is 0
# Sequence for node NODE_118 is ...
# Sequence for node XP_006778968.2 is ...
# Difference Score between NODE_118 and XP_006778968.2 is 108
# Penalty Score between NODE_118 and XP_006778968.2 is 34
# Total score is 142
# Sequence for node NODE_118 is ...
# Sequence for node XP_006096650.1 is ...
# Difference Score between NODE_118 and XP_006096650.1 is 0
# Penalty Score between NODE_118 and XP_006096650.1 is 0
# Total score is 0
# Sequence for node NODE_119 is ...
# Sequence for node NODE_125 is ...
# Difference Score between NODE_119 and NODE_125 is 0
# Penalty Score between NODE_119 and NODE_125 is 0
# Total score is 0
# Sequence for node NODE_119 is ...
# Sequence for node NODE_126 is ...
# Difference Score between NODE_119 and NODE_126 is 0
# Penalty Score between NODE_119 and NODE_126 is 0
# Total score is 0
# Sequence for node NODE_120 is ...
# Sequence for node XP_007191063.1 is ...
# Difference Score between NODE_120 and XP_007191063.1 is 0
# Penalty Score between NODE_120 and XP_007191063.1 is 0
# Total score is 0
# Sequence for node NODE_120 is ...
# Sequence for node NODE_127 is ...
# Difference Score between NODE_120 and NODE_127 is 0
# Penalty Score between NODE_120 and NODE_127 is 0
# Total score is 0
# Sequence for node NODE_121 is ...
# Sequence for node XP_020757615.1 is ...
# Difference Score between NODE_121 and XP_020757615.1 is 0
# Penalty Score between NODE_121 and XP_020757615.1 is 0
# Total score is 0
# Sequence for node NODE_121 is ...
# Sequence for node NODE_128 is ...
# Difference Score between NODE_121 and NODE_128 is 0
# Penalty Score between NODE_121 and NODE_128 is 0
# Total score is 0
# Sequence for node NODE_122 is ...
# Sequence for node NODE_129 is ...
# Difference Score between NODE_122 and NODE_129 is 3
# Penalty Score between NODE_122 and NODE_129 is 2
# Total score is 5
# Sequence for node NODE_122 is ...
# Sequence for node XP_004866353.1 is ...
# Difference Score between NODE_122 and XP_004866353.1 is 5
# Penalty Score between NODE_122 and XP_004866353.1 is 8
# Total score is 13
# Sequence for node NODE_123 is ...
# Sequence for node NODE_130 is ...
# Difference Score between NODE_123 and NODE_130 is 6
# Penalty Score between NODE_123 and NODE_130 is 8
# Total score is 14
# Sequence for node NODE_123 is ...
# Sequence for node XP_020016209.1 is ...
# Difference Score between NODE_123 and XP_020016209.1 is 5
# Penalty Score between NODE_123 and XP_020016209.1 is 6
# Total score is 11
# Sequence for node NODE_124 is ...
# Sequence for node XP_002815089.3 is ...
# Difference Score between NODE_124 and XP_002815089.3 is 0
# Penalty Score between NODE_124 and XP_002815089.3 is 0
# Total score is 0
# Sequence for node NODE_124 is ...
# Sequence for node NODE_131 is ...
# Difference Score between NODE_124 and NODE_131 is 0
# Penalty Score between NODE_124 and NODE_131 is 0
# Total score is 0
# Sequence for node NODE_125 is ...
# Sequence for node XP_004748170.1 is ...
# Difference Score between NODE_125 and XP_004748170.1 is 0
# Penalty Score between NODE_125 and XP_004748170.1 is 0
# Total score is 0
# Sequence for node NODE_125 is ...
# Sequence for node XP_022370877.1 is ...
# Difference Score between NODE_125 and XP_022370877.1 is 0
# Penalty Score between NODE_125 and XP_022370877.1 is 0
# Total score is 0
# Sequence for node NODE_126 is ...
# Sequence for node XP_004411289.1 is ...
# Difference Score between NODE_126 and XP_004411289.1 is 2
# Penalty Score between NODE_126 and XP_004411289.1 is 2
# Total score is 4
# Sequence for node NODE_126 is ...
# Sequence for node NODE_132 is ...
# Difference Score between NODE_126 and NODE_132 is 0
# Penalty Score between NODE_126 and NODE_132 is 0
# Total score is 0
# Sequence for node NODE_127 is ...
# Sequence for node NODE_133 is ...
# Difference Score between NODE_127 and NODE_133 is 0
# Penalty Score between NODE_127 and NODE_133 is 0
# Total score is 0
# Sequence for node NODE_127 is ...
# Sequence for node XP_007452210.1 is ...
# Difference Score between NODE_127 and XP_007452210.1 is 0
# Penalty Score between NODE_127 and XP_007452210.1 is 0
# Total score is 0
# Sequence for node NODE_128 is ...
# Sequence for node NODE_134 is ...
# Difference Score between NODE_128 and NODE_134 is 0
# Penalty Score between NODE_128 and NODE_134 is 0
# Total score is 0
# Sequence for node NODE_128 is ...
# Sequence for node NODE_135 is ...
# Difference Score between NODE_128 and NODE_135 is 0
# Penalty Score between NODE_128 and NODE_135 is 0
# Total score is 0
# Sequence for node NODE_129 is ...
# Sequence for node XP_003468093.1 is ...
# Difference Score between NODE_129 and XP_003468093.1 is 8
# Penalty Score between NODE_129 and XP_003468093.1 is 2
# Total score is 10
# Sequence for node NODE_129 is ...
# Sequence for node XP_005406339.2 is ...
# Difference Score between NODE_129 and XP_005406339.2 is 53
# Penalty Score between NODE_129 and XP_005406339.2 is 22
# Total score is 75
# Sequence for node NODE_130 is ...
# Sequence for node XP_012879182.1 is ...
# Difference Score between NODE_130 and XP_012879182.1 is 6
# Penalty Score between NODE_130 and XP_012879182.1 is 10
# Total score is 16
# Sequence for node NODE_130 is ...
# Sequence for node NODE_136 is ...
# Difference Score between NODE_130 and NODE_136 is 8
# Penalty Score between NODE_130 and NODE_136 is 2
# Total score is 10
# Sequence for node NODE_131 is ...
# Sequence for node NODE_137 is ...
# Difference Score between NODE_131 and NODE_137 is 0
# Penalty Score between NODE_131 and NODE_137 is 0
# Total score is 0
# Sequence for node NODE_131 is ...
# Sequence for node NODE_138 is ...
# Difference Score between NODE_131 and NODE_138 is 0
# Penalty Score between NODE_131 and NODE_138 is 0
# Total score is 0
# Sequence for node NODE_132 is ...
# Sequence for node XP_021540185.1 is ...
# Difference Score between NODE_132 and XP_021540185.1 is 0
# Penalty Score between NODE_132 and XP_021540185.1 is 0
# Total score is 0
# Sequence for node NODE_132 is ...
# Sequence for node XP_006727242.1 is ...
# Difference Score between NODE_132 and XP_006727242.1 is 0
# Penalty Score between NODE_132 and XP_006727242.1 is 0
# Total score is 0
# Sequence for node NODE_133 is ...
# Sequence for node NODE_139 is ...
# Difference Score between NODE_133 and NODE_139 is 0
# Penalty Score between NODE_133 and NODE_139 is 0
# Total score is 0
# Sequence for node NODE_133 is ...
# Sequence for node XP_004269644.1 is ...
# Difference Score between NODE_133 and XP_004269644.1 is 0
# Penalty Score between NODE_133 and XP_004269644.1 is 0
# Total score is 0
# Sequence for node NODE_134 is ...
# Sequence for node XP_006061937.1 is ...
# Difference Score between NODE_134 and XP_006061937.1 is 0
# Penalty Score between NODE_134 and XP_006061937.1 is 0
# Total score is 0
# Sequence for node NODE_134 is ...
# Sequence for node NODE_140 is ...
# Difference Score between NODE_134 and NODE_140 is 0
# Penalty Score between NODE_134 and NODE_140 is 0
# Total score is 0
# Sequence for node NODE_135 is ...
# Sequence for node XP_017904722.1 is ...
# Difference Score between NODE_135 and XP_017904722.1 is 0
# Penalty Score between NODE_135 and XP_017904722.1 is 0
# Total score is 0
# Sequence for node NODE_135 is ...
# Sequence for node XP_011994146.1 is ...
# Difference Score between NODE_135 and XP_011994146.1 is 0
# Penalty Score between NODE_135 and XP_011994146.1 is 0
# Total score is 0
# Sequence for node NODE_136 is ...
# Sequence for node XP_004671492.1 is ...
# Difference Score between NODE_136 and XP_004671492.1 is 8
# Penalty Score between NODE_136 and XP_004671492.1 is 12
# Total score is 20
# Sequence for node NODE_136 is ...
# Sequence for node NODE_141 is ...
# Difference Score between NODE_136 and NODE_141 is 1
# Penalty Score between NODE_136 and NODE_141 is 2
# Total score is 3
# Sequence for node NODE_137 is ...
# Sequence for node XP_003929520.1 is ...
# Difference Score between NODE_137 and XP_003929520.1 is 0
# Penalty Score between NODE_137 and XP_003929520.1 is 0
# Total score is 0
# Sequence for node NODE_137 is ...
# Sequence for node NODE_142 is ...
# Difference Score between NODE_137 and NODE_142 is 0
# Penalty Score between NODE_137 and NODE_142 is 0
# Total score is 0
# Sequence for node NODE_138 is ...
# Sequence for node NODE_143 is ...
# Difference Score between NODE_138 and NODE_143 is 0
# Penalty Score between NODE_138 and NODE_143 is 0
# Total score is 0
# Sequence for node NODE_138 is ...
# Sequence for node NODE_144 is ...
# Difference Score between NODE_138 and NODE_144 is 0
# Penalty Score between NODE_138 and NODE_144 is 0
# Total score is 0
# Sequence for node NODE_139 is ...
# Sequence for node XP_019783337.1 is ...
# Difference Score between NODE_139 and XP_019783337.1 is 0
# Penalty Score between NODE_139 and XP_019783337.1 is 0
# Total score is 0
# Sequence for node NODE_139 is ...
# Sequence for node NODE_145 is ...
# Difference Score between NODE_139 and NODE_145 is 0
# Penalty Score between NODE_139 and NODE_145 is 0
# Total score is 0
# Sequence for node NODE_140 is ...
# Sequence for node NODE_146 is ...
# Difference Score between NODE_140 and NODE_146 is 0
# Penalty Score between NODE_140 and NODE_146 is 0
# Total score is 0
# Sequence for node NODE_140 is ...
# Sequence for node XP_005896309.1 is ...
# Difference Score between NODE_140 and XP_005896309.1 is 0
# Penalty Score between NODE_140 and XP_005896309.1 is 0
# Total score is 0
# Sequence for node NODE_141 is ...
# Sequence for node NODE_147 is ...
# Difference Score between NODE_141 and NODE_147 is 1
# Penalty Score between NODE_141 and NODE_147 is 2
# Total score is 3
# Sequence for node NODE_141 is ...
# Sequence for node XP_008842003.1 is ...
# Difference Score between NODE_141 and XP_008842003.1 is 0
# Penalty Score between NODE_141 and XP_008842003.1 is 0
# Total score is 0
# Sequence for node NODE_142 is ...
# Sequence for node NODE_148 is ...
# Difference Score between NODE_142 and NODE_148 is 0
# Penalty Score between NODE_142 and NODE_148 is 0
# Total score is 0
# Sequence for node NODE_142 is ...
# Sequence for node XP_017824361.1 is ...
# Difference Score between NODE_142 and XP_017824361.1 is 0
# Penalty Score between NODE_142 and XP_017824361.1 is 0
# Total score is 0
# Sequence for node NODE_143 is ...
# Sequence for node XP_007997667.1 is ...
# Difference Score between NODE_143 and XP_007997667.1 is 0
# Penalty Score between NODE_143 and XP_007997667.1 is 0
# Total score is 0
# Sequence for node NODE_143 is ...
# Sequence for node NODE_149 is ...
# Difference Score between NODE_143 and NODE_149 is 0
# Penalty Score between NODE_143 and NODE_149 is 0
# Total score is 0
# Sequence for node NODE_144 is ...
# Sequence for node BAF82691.1 is ...
# Difference Score between NODE_144 and BAF82691.1 is 0
# Penalty Score between NODE_144 and BAF82691.1 is 0
# Total score is 0
# Sequence for node NODE_144 is ...
# Sequence for node NODE_150 is ...
# Difference Score between NODE_144 and NODE_150 is 0
# Penalty Score between NODE_144 and NODE_150 is 0
# Total score is 0
# Sequence for node NODE_145 is ...
# Sequence for node XP_022422796.1 is ...
# Difference Score between NODE_145 and XP_022422796.1 is 0
# Penalty Score between NODE_145 and XP_022422796.1 is 0
# Total score is 0
# Sequence for node NODE_145 is ...
# Sequence for node XP_007100655.1 is ...
# Difference Score between NODE_145 and XP_007100655.1 is 0
# Penalty Score between NODE_145 and XP_007100655.1 is 0
# Total score is 0
# Sequence for node NODE_146 is ...
# Sequence for node DAA28880.1 is ...
# Difference Score between NODE_146 and DAA28880.1 is 0
# Penalty Score between NODE_146 and DAA28880.1 is 0
# Total score is 0
# Sequence for node NODE_146 is ...
# Sequence for node NP_001069518.1 is ...
# Difference Score between NODE_146 and NP_001069518.1 is 0
# Penalty Score between NODE_146 and NP_001069518.1 is 0
# Total score is 0
# Sequence for node NODE_147 is ...
# Sequence for node NODE_151 is ...
# Difference Score between NODE_147 and NODE_151 is 0
# Penalty Score between NODE_147 and NODE_151 is 0
# Total score is 0
# Sequence for node NODE_147 is ...
# Sequence for node NODE_152 is ...
# Difference Score between NODE_147 and NODE_152 is 0
# Penalty Score between NODE_147 and NODE_152 is 0
# Total score is 0
# Sequence for node NODE_148 is ...
# Sequence for node XP_012291909.1 is ...
# Difference Score between NODE_148 and XP_012291909.1 is 0
# Penalty Score between NODE_148 and XP_012291909.1 is 0
# Total score is 0
# Sequence for node NODE_148 is ...
# Sequence for node XP_017364494.1 is ...
# Difference Score between NODE_148 and XP_017364494.1 is 0
# Penalty Score between NODE_148 and XP_017364494.1 is 0
# Total score is 0
# Sequence for node NODE_149 is ...
# Sequence for node NODE_153 is ...
# Difference Score between NODE_149 and NODE_153 is 0
# Penalty Score between NODE_149 and NODE_153 is 0
# Total score is 0
# Sequence for node NODE_149 is ...
# Sequence for node NODE_154 is ...
# Difference Score between NODE_149 and NODE_154 is 0
# Penalty Score between NODE_149 and NODE_154 is 0
# Total score is 0
# Sequence for node NODE_150 is ...
# Sequence for node XP_004040295.1 is ...
# Difference Score between NODE_150 and XP_004040295.1 is 0
# Penalty Score between NODE_150 and XP_004040295.1 is 0
# Total score is 0
# Sequence for node NODE_150 is ...
# Sequence for node NODE_155 is ...
# Difference Score between NODE_150 and NODE_155 is 0
# Penalty Score between NODE_150 and NODE_155 is 0
# Total score is 0
# Sequence for node NODE_151 is ...
# Sequence for node NP_001019950.1 is ...
# Difference Score between NODE_151 and NP_001019950.1 is 0
# Penalty Score between NODE_151 and NP_001019950.1 is 0
# Total score is 0
# Sequence for node NODE_151 is ...
# Sequence for node NODE_156 is ...
# Difference Score between NODE_151 and NODE_156 is 0
# Penalty Score between NODE_151 and NODE_156 is 0
# Total score is 0
# Sequence for node NODE_152 is ...
# Sequence for node NODE_157 is ...
# Difference Score between NODE_152 and NODE_157 is 0
# Penalty Score between NODE_152 and NODE_157 is 0
# Total score is 0
# Sequence for node NODE_152 is ...
# Sequence for node XP_021488968.1 is ...
# Difference Score between NODE_152 and XP_021488968.1 is 1
# Penalty Score between NODE_152 and XP_021488968.1 is 2
# Total score is 3
# Sequence for node NODE_153 is ...
# Sequence for node NODE_158 is ...
# Difference Score between NODE_153 and NODE_158 is 0
# Penalty Score between NODE_153 and NODE_158 is 0
# Total score is 0
# Sequence for node NODE_153 is ...
# Sequence for node XP_005555686.1 is ...
# Difference Score between NODE_153 and XP_005555686.1 is 0
# Penalty Score between NODE_153 and XP_005555686.1 is 0
# Total score is 0
# Sequence for node NODE_154 is ...
# Sequence for node XP_011884345.1 is ...
# Difference Score between NODE_154 and XP_011884345.1 is 0
# Penalty Score between NODE_154 and XP_011884345.1 is 0
# Total score is 0
# Sequence for node NODE_154 is ...
# Sequence for node EHH26107.1 is ...
# Difference Score between NODE_154 and EHH26107.1 is 129
# Penalty Score between NODE_154 and EHH26107.1 is 36
# Total score is 165
# Sequence for node NODE_155 is ...
# Sequence for node XP_526649.2 is ...
# Difference Score between NODE_155 and XP_526649.2 is 0
# Penalty Score between NODE_155 and XP_526649.2 is 0
# Total score is 0
# Sequence for node NODE_155 is ...
# Sequence for node NP_898898.1 is ...
# Difference Score between NODE_155 and NP_898898.1 is 0
# Penalty Score between NODE_155 and NP_898898.1 is 0
# Total score is 0
# Sequence for node NODE_156 is ...
# Sequence for node XP_021052700.1 is ...
# Difference Score between NODE_156 and XP_021052700.1 is 0
# Penalty Score between NODE_156 and XP_021052700.1 is 0
# Total score is 0
# Sequence for node NODE_156 is ...
# Sequence for node NODE_159 is ...
# Difference Score between NODE_156 and NODE_159 is 0
# Penalty Score between NODE_156 and NODE_159 is 0
# Total score is 0
# Sequence for node NODE_157 is ...
# Sequence for node XP_005082857.1 is ...
# Difference Score between NODE_157 and XP_005082857.1 is 2
# Penalty Score between NODE_157 and XP_005082857.1 is 2
# Total score is 4
# Sequence for node NODE_157 is ...
# Sequence for node NODE_160 is ...
# Difference Score between NODE_157 and NODE_160 is 0
# Penalty Score between NODE_157 and NODE_160 is 0
# Total score is 0
# Sequence for node NODE_158 is ...
# Sequence for node XP_003899118.1 is ...
# Difference Score between NODE_158 and XP_003899118.1 is 0
# Penalty Score between NODE_158 and XP_003899118.1 is 0
# Total score is 0
# Sequence for node NODE_158 is ...
# Sequence for node NODE_161 is ...
# Difference Score between NODE_158 and NODE_161 is 0
# Penalty Score between NODE_158 and NODE_161 is 0
# Total score is 0
# Sequence for node NODE_159 is ...
# Sequence for node XP_021014502.1 is ...
# Difference Score between NODE_159 and XP_021014502.1 is 0
# Penalty Score between NODE_159 and XP_021014502.1 is 0
# Total score is 0
# Sequence for node NODE_159 is ...
# Sequence for node NP_082092.2 is ...
# Difference Score between NODE_159 and NP_082092.2 is 0
# Penalty Score between NODE_159 and NP_082092.2 is 0
# Total score is 0
# Sequence for node NODE_160 is ...
# Sequence for node XP_007624001.1 is ...
# Difference Score between NODE_160 and XP_007624001.1 is 95
# Penalty Score between NODE_160 and XP_007624001.1 is 32
# Total score is 127
# Sequence for node NODE_160 is ...
# Sequence for node XP_005357351.1 is ...
# Difference Score between NODE_160 and XP_005357351.1 is 0
# Penalty Score between NODE_160 and XP_005357351.1 is 0
# Total score is 0
# Sequence for node NODE_161 is ...
# Sequence for node NODE_162 is ...
# Difference Score between NODE_161 and NODE_162 is 0
# Penalty Score between NODE_161 and NODE_162 is 0
# Total score is 0
# Sequence for node NODE_161 is ...
# Sequence for node XP_023051615.1 is ...
# Difference Score between NODE_161 and XP_023051615.1 is 0
# Penalty Score between NODE_161 and XP_023051615.1 is 0
# Total score is 0
# Sequence for node NODE_162 is ...
# Sequence for node NODE_163 is ...
# Difference Score between NODE_162 and NODE_163 is 0
# Penalty Score between NODE_162 and NODE_163 is 0
# Total score is 0
# Sequence for node NODE_162 is ...
# Sequence for node XP_010371512.1 is ...
# Difference Score between NODE_162 and XP_010371512.1 is 0
# Penalty Score between NODE_162 and XP_010371512.1 is 0
# Total score is 0
# Sequence for node NODE_163 is ...
# Sequence for node XP_017708554.1 is ...
# Difference Score between NODE_163 and XP_017708554.1 is 0
# Penalty Score between NODE_163 and XP_017708554.1 is 0
# Total score is 0
# Sequence for node NODE_163 is ...
# Sequence for node XP_011801112.1 is ...
# Difference Score between NODE_163 and XP_011801112.1 is 0
# Penalty Score between NODE_163 and XP_011801112.1 is 0
# Total score is 0
