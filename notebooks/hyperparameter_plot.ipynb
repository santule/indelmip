# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob, os
import numpy as np
plot_output_folder = '/Users/sanjanatule/Documents/uq/Projects/mipindel/plots_for_paper/'

# %%
plt.rc('axes',  titlesize=15)     # fontsize of the axes title
plt.rc('axes',  labelsize=10)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)    # fontsize of the tick labels
plt.rc('legend',fontsize=10)    # legend fontsize
plt.rc('font',  size=12)          # controls default text sizes
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Computer Modern Serif"
colors = sns.color_palette('deep')
plt.style.use('seaborn')
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style("ticks")
plt.rcParams.update({'figure.autolayout': True})

# %%
# dataset - t300d0.5s0.5

sns.set_context('talk')
alpha = [0,1,2,3,4,5,6,7,8]
indel_score = [2297,2292,2287,2285,2285,2283,2283,2283,2283]
plt.ylim((2200,2300))
plt.bar(alpha,indel_score,color = '#58181F',align='center',width=0.8)
plt.xlabel('Alpha')
plt.ylabel('Indel score')
filename = plot_output_folder + "Alpha_experiment_plot.jpg"
plt.savefig(filename,dpi=1000)
plt.show()
